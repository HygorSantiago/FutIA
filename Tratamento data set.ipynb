# %% [markdown]
# ## Importação das bibliotecas

# %%
import pandas as pd

# %% [markdown]
# ## Funções

# %% [markdown]
# ### Função de sequeciamento

# %%
def sequencing(df, field_to_sequence, window, fields_to_group:list, fields_to_sort):
    if field_to_sequence not in list(df):
        print('field', field_to_sequence, 'is not in dataframe')
    for f in fields_to_group:
        if f not in list(df):
            print('field', f, 'is not in dataframe')
    return df.sort_values(
            fields_to_sort
        ).assign(
        **{'Seq_{field}'.format(field=field_to_sequence): lambda x: pd.concat(
            [
                dpg.sum()
                for dpg in x[
                    fields_to_group + [field_to_sequence]
                ].groupby(
                    by=fields_to_group
                )[[field_to_sequence]].rolling(window)
            ]
        ).values}
    )

# %% [markdown]
# ### Função de sequeciamento para dicionario

# %%
def seq_to_dict(seq, field_name):
    return {field_name+str(k):c for k, c in enumerate(list(seq)[::-1])}

# %% [markdown]
# ## Criação dos dataframes

# %% [markdown]
# ### Carga dos jogos

# %%
game_file = 'games_9.parquet'


df = pd.read_parquet('games_9.parquet').query("`Camp.` == 'Premier League'").reset_index(drop=True)
df_hist = df.query("Resultado != ''").reset_index(drop=True)

# %% [markdown]
# ### Rodadas do ultimo ano

# %%
df_rodada = df_hist.query(
    "Ano == '{ano}'".format(
        ano = df_hist['Ano'].max()
    )
).assign(
    **{
        'rodada_text': lambda x: x['Rodada'].apply(
            lambda y: ' '.join(y.split(' ')[:-1])
        )
        , 'rodada_number': lambda x: x['Rodada'].apply(
            lambda y: int(y.split(' ')[-1])
        )
    }
)[
    ['Rodada', 'rodada_text', 'rodada_number']
]

# %%
df_next_round
# Out:
#            Data Horário           Camp.               Rodada  Dia      Local  \
# 6095 2022-12-26   20:00  Premier League  Rodada da semana 17  seg    Em casa
# 6132 2022-12-28   20:00  Premier League  Rodada da semana 17  qua  Visitante
# 6172 2022-12-26   15:00  Premier League  Rodada da semana 17  seg  Visitante
# 6209 2022-12-26   12:30  Premier League  Rodada da semana 17  seg  Visitante
# 6248 2022-12-27   20:00  Premier League  Rodada da semana 17  ter    Em casa
# 6286 2022-12-26   17:30  Premier League  Rodada da semana 17  seg  Visitante
# 6324 2022-12-26   15:00  Premier League  Rodada da semana 17  seg  Visitante
# 6361 2022-12-27   17:30  Premier League  Rodada da semana 17  ter    Em casa
# 6399 2022-12-26   15:00  Premier League  Rodada da semana 17  seg  Visitante
# 6438 2022-12-26   12:30  Premier League  Rodada da semana 17  seg    Em casa
# 6476 2022-12-26   15:00  Premier League  Rodada da semana 17  seg    Em casa
# 6514 2022-12-26   17:30  Premier League  Rodada da semana 17  seg    Em casa
# 6552 2022-12-26   15:00  Premier League  Rodada da semana 17  seg    Em casa
# 6590 2022-12-27   17:30  Premier League  Rodada da semana 17  ter  Visitante
# 6628 2022-12-28   20:00  Premier League  Rodada da semana 17  qua    Em casa
# 6666 2022-12-26   20:00  Premier League  Rodada da semana 17  seg  Visitante
# 6704 2022-12-26   15:00  Premier League  Rodada da semana 17  seg    Em casa
# 6742 2022-12-27   20:00  Premier League  Rodada da semana 17  ter  Visitante
# 6780 2022-12-26   15:00  Premier League  Rodada da semana 17  seg    Em casa
# 6818 2022-12-26   15:00  Premier League  Rodada da semana 17  seg  Visitante
#
#      Resultado GP GC  Oponente  ... Capitão Formação Árbitro  \
# 6095                  7c21e445  ...
# 6132                  5bfb9659  ...
# 6172                  a2d435b3  ...
# 6209                  cd051869  ...
# 6248                  e4a775cb  ...
# 6286                  8602292d  ...
# 6324                  33c895d4  ...
# 6361                  4ba7cbea  ...
# 6399                  47c64c55  ...
# 6438                  361ca564  ...
# 6476                  fd962109  ...
# 6514                  822bd0ba  ...
# 6552                  b2b47a98  ...
# 6590                  cff3d9bb  ...
# 6628                  b8fd03ef  ...
# 6666                  18bb7c10  ...
# 6704                  8cec06e1  ...
# 6742                  19538871  ...
# 6780                  d07537b9  ...
# 6818                  d3fd31cc  ...
#
#                                    Relatório da Partida Notas        id  \
# 6095  https://fbref.com/pt/stathead/matchup/teams/7c...        18bb7c10
# 6132  https://fbref.com/pt/stathead/matchup/teams/b8...        5bfb9659
# 6172  https://fbref.com/pt/stathead/matchup/teams/b2...        a2d435b3
# 6209  https://fbref.com/pt/stathead/matchup/teams/cd...        361ca564
# 6248  https://fbref.com/pt/stathead/matchup/teams/e4...        19538871
# 6286  https://fbref.com/pt/stathead/matchup/teams/86...        822bd0ba
# 6324  https://fbref.com/pt/stathead/matchup/teams/d0...        33c895d4
# 6361  https://fbref.com/pt/stathead/matchup/teams/cf...        4ba7cbea
# 6399  https://fbref.com/pt/stathead/matchup/teams/fd...        47c64c55
# 6438  https://fbref.com/pt/stathead/matchup/teams/cd...        361ca564
# 6476  https://fbref.com/pt/stathead/matchup/teams/fd...        47c64c55
# 6514  https://fbref.com/pt/stathead/matchup/teams/86...        822bd0ba
# 6552  https://fbref.com/pt/stathead/matchup/teams/b2...        a2d435b3
# 6590  https://fbref.com/pt/stathead/matchup/teams/cf...        4ba7cbea
# 6628  https://fbref.com/pt/stathead/matchup/teams/b8...        5bfb9659
# 6666  https://fbref.com/pt/stathead/matchup/teams/7c...        18bb7c10
# 6704  https://fbref.com/pt/stathead/matchup/teams/d3...        8cec06e1
# 6742  https://fbref.com/pt/stathead/matchup/teams/e4...        19538871
# 6780  https://fbref.com/pt/stathead/matchup/teams/d0...        33c895d4
# 6818  https://fbref.com/pt/stathead/matchup/teams/d3...        8cec06e1
#
#      fgk_equipe        Ano xG xGA
# 6095   18bb7c10  2022-2023
# 6132   b8fd03ef  2022-2023
# 6172   b2b47a98  2022-2023
# 6209   361ca564  2022-2023
# 6248   19538871  2022-2023
# 6286   822bd0ba  2022-2023
# 6324   d07537b9  2022-2023
# 6361   cff3d9bb  2022-2023
# 6399   fd962109  2022-2023
# 6438   cd051869  2022-2023
# 6476   47c64c55  2022-2023
# 6514   8602292d  2022-2023
# 6552   a2d435b3  2022-2023
# 6590   4ba7cbea  2022-2023
# 6628   5bfb9659  2022-2023
# 6666   7c21e445  2022-2023
# 6704   d3fd31cc  2022-2023
# 6742   e4a775cb  2022-2023
# 6780   33c895d4  2022-2023
# 6818   8cec06e1  2022-2023
#
# [20 rows x 22 columns]

# %% [markdown]
# ### Jogos da próxima rodada

# %%
df_next_round = df.query(
    "Ano == '{ano}'".format(
        ano = df_hist['Ano'].max()
    )
    + " and Rodada == '{rodada_text} {rodada_number}'".format(
        rodada_text = df_rodada['rodada_text'].max()
        , rodada_number = df_rodada['rodada_number'].max()+1
    )
)
df_next_round
# Out:
#            Data Horário           Camp.               Rodada  Dia      Local  \
# 6095 2022-12-26   20:00  Premier League  Rodada da semana 17  seg    Em casa
# 6132 2022-12-28   20:00  Premier League  Rodada da semana 17  qua  Visitante
# 6172 2022-12-26   15:00  Premier League  Rodada da semana 17  seg  Visitante
# 6209 2022-12-26   12:30  Premier League  Rodada da semana 17  seg  Visitante
# 6248 2022-12-27   20:00  Premier League  Rodada da semana 17  ter    Em casa
# 6286 2022-12-26   17:30  Premier League  Rodada da semana 17  seg  Visitante
# 6324 2022-12-26   15:00  Premier League  Rodada da semana 17  seg  Visitante
# 6361 2022-12-27   17:30  Premier League  Rodada da semana 17  ter    Em casa
# 6399 2022-12-26   15:00  Premier League  Rodada da semana 17  seg  Visitante
# 6438 2022-12-26   12:30  Premier League  Rodada da semana 17  seg    Em casa
# 6476 2022-12-26   15:00  Premier League  Rodada da semana 17  seg    Em casa
# 6514 2022-12-26   17:30  Premier League  Rodada da semana 17  seg    Em casa
# 6552 2022-12-26   15:00  Premier League  Rodada da semana 17  seg    Em casa
# 6590 2022-12-27   17:30  Premier League  Rodada da semana 17  ter  Visitante
# 6628 2022-12-28   20:00  Premier League  Rodada da semana 17  qua    Em casa
# 6666 2022-12-26   20:00  Premier League  Rodada da semana 17  seg  Visitante
# 6704 2022-12-26   15:00  Premier League  Rodada da semana 17  seg    Em casa
# 6742 2022-12-27   20:00  Premier League  Rodada da semana 17  ter  Visitante
# 6780 2022-12-26   15:00  Premier League  Rodada da semana 17  seg    Em casa
# 6818 2022-12-26   15:00  Premier League  Rodada da semana 17  seg  Visitante
#
#      Resultado GP GC  Oponente  ... Capitão Formação Árbitro  \
# 6095                  7c21e445  ...
# 6132                  5bfb9659  ...
# 6172                  a2d435b3  ...
# 6209                  cd051869  ...
# 6248                  e4a775cb  ...
# 6286                  8602292d  ...
# 6324                  33c895d4  ...
# 6361                  4ba7cbea  ...
# 6399                  47c64c55  ...
# 6438                  361ca564  ...
# 6476                  fd962109  ...
# 6514                  822bd0ba  ...
# 6552                  b2b47a98  ...
# 6590                  cff3d9bb  ...
# 6628                  b8fd03ef  ...
# 6666                  18bb7c10  ...
# 6704                  8cec06e1  ...
# 6742                  19538871  ...
# 6780                  d07537b9  ...
# 6818                  d3fd31cc  ...
#
#                                    Relatório da Partida Notas        id  \
# 6095  https://fbref.com/pt/stathead/matchup/teams/7c...        18bb7c10
# 6132  https://fbref.com/pt/stathead/matchup/teams/b8...        5bfb9659
# 6172  https://fbref.com/pt/stathead/matchup/teams/b2...        a2d435b3
# 6209  https://fbref.com/pt/stathead/matchup/teams/cd...        361ca564
# 6248  https://fbref.com/pt/stathead/matchup/teams/e4...        19538871
# 6286  https://fbref.com/pt/stathead/matchup/teams/86...        822bd0ba
# 6324  https://fbref.com/pt/stathead/matchup/teams/d0...        33c895d4
# 6361  https://fbref.com/pt/stathead/matchup/teams/cf...        4ba7cbea
# 6399  https://fbref.com/pt/stathead/matchup/teams/fd...        47c64c55
# 6438  https://fbref.com/pt/stathead/matchup/teams/cd...        361ca564
# 6476  https://fbref.com/pt/stathead/matchup/teams/fd...        47c64c55
# 6514  https://fbref.com/pt/stathead/matchup/teams/86...        822bd0ba
# 6552  https://fbref.com/pt/stathead/matchup/teams/b2...        a2d435b3
# 6590  https://fbref.com/pt/stathead/matchup/teams/cf...        4ba7cbea
# 6628  https://fbref.com/pt/stathead/matchup/teams/b8...        5bfb9659
# 6666  https://fbref.com/pt/stathead/matchup/teams/7c...        18bb7c10
# 6704  https://fbref.com/pt/stathead/matchup/teams/d3...        8cec06e1
# 6742  https://fbref.com/pt/stathead/matchup/teams/e4...        19538871
# 6780  https://fbref.com/pt/stathead/matchup/teams/d0...        33c895d4
# 6818  https://fbref.com/pt/stathead/matchup/teams/d3...        8cec06e1
#
#      fgk_equipe        Ano xG xGA
# 6095   18bb7c10  2022-2023
# 6132   b8fd03ef  2022-2023
# 6172   b2b47a98  2022-2023
# 6209   361ca564  2022-2023
# 6248   19538871  2022-2023
# 6286   822bd0ba  2022-2023
# 6324   d07537b9  2022-2023
# 6361   cff3d9bb  2022-2023
# 6399   fd962109  2022-2023
# 6438   cd051869  2022-2023
# 6476   47c64c55  2022-2023
# 6514   8602292d  2022-2023
# 6552   a2d435b3  2022-2023
# 6590   4ba7cbea  2022-2023
# 6628   5bfb9659  2022-2023
# 6666   7c21e445  2022-2023
# 6704   d3fd31cc  2022-2023
# 6742   e4a775cb  2022-2023
# 6780   33c895d4  2022-2023
# 6818   8cec06e1  2022-2023
#
# [20 rows x 22 columns]

# %% [markdown]
# ## Etapa 1

# %% [markdown]
# ### Tratamento
#
# <ul>
#     <li> Retirar partidas Canceladas </li>
#     <li> Retirar partidas adiadas </li>
#     <li> Seleção dos campos </li>
#     <ul>
#         <li> <b>Resultado</b> - Resultado da partida</li>
#         <li> <b>fgk_equipe</b> - código da equipe</li>
#         <li> <b>Ano</b> - Ano do campeonato</li>
#         <li> <b>Rodada</b> - Rodada do campeonato</li>
#         <li> <b>Local</b> - Local da partida</li>
#         <li> <b>GP</b> - Gols a favor da partida</li>
#         <li> <b>GC</b> - Gols contra da partida</li>
#         <li> <b>Oponente</b> - código do oponente</li>
#         <li> <b>id</b> - código da partida</li>
#     </ul>
#     <li> Tratamento da "Rodada" para conter apenas números </li>
#     <li> Ordenação do dataframe por: fgk_equipe, Ano, Rodada </li>
#     <li> Tratamento do "Local" substituindo: "Visitante" por 0 e "Em casa" por 1 </li>
# </ul>

# %%
df_1 = df_hist.query(
    "not Notas.str.contains('Partida Cancelada')" # Retira partida Cancelada
    + " and not Notas.str.contains('Partida adiada')" # Retirada partida adiada
    , engine='python'
)[
    ['Resultado', 'fgk_equipe', 'Ano', 'Rodada', 'Local', 'GP', 'GC', 'Oponente', 'id']
].assign(
    **{'Rodada': lambda x: x['Rodada'].apply(
        lambda y: int(y.split(' ')[-1])
    )}
).sort_values(
    ['fgk_equipe', 'Ano', 'Rodada']
).replace(
    {'Local':{'Visitante':'0', 'Em casa':'1'}}
).assign(
    **{
        'GP': lambda x: x['GP'].apply(
            lambda y: '9' if int(y) > 9 else y
        )
        , 'GC': lambda x: x['GC'].apply(
            lambda y: '9' if int(y) > 9 else y
        )
    }
)
df_1
# Out:
#      Resultado fgk_equipe        Ano  Rodada Local GP GC  Oponente        id
# 304          D   17892952  2014-2015       1     1  0  1  8602292d  0a235dd1
# 305          E   17892952  2014-2015       2     0  1  1  bd8769d1  ee81980a
# 306          V   17892952  2014-2015       3     0  1  0  b8fd03ef  9e73f0ce
# 307          D   17892952  2014-2015       4     1  0  1  a2d435b3  238517ea
# 308          E   17892952  2014-2015       5     0  2  2  a757999c  e8592bc3
# ...        ...        ...        ...     ...   ... .. ..       ...       ...
# 6204         V   fd962109  2022-2023      12     1  3  0  8602292d  e6102606
# 6205         V   fd962109  2022-2023      13     0  3  2  5bfb9659  d7b30e2b
# 6206         E   fd962109  2022-2023      14     1  0  0  d3fd31cc  9c4402e1
# 6207         D   fd962109  2022-2023      15     0  1  2  b8fd03ef  6ef27b3c
# 6208         D   fd962109  2022-2023      16     1  1  2  19538871  af75b6b0
#
# [6372 rows x 9 columns]

# %%
# Out:
# array(['1', '0', '2', '3', '4', '7', '5', '6', '8', '9'], dtype=object)

# %% [markdown]
# ### Verificação de NA

# %%
df_1.isna().sum()
# Out:
# Resultado     0
# fgk_equipe    0
# Ano           0
# Rodada        0
# Local         0
# GP            0
# GC            0
# Oponente      0
# id            0
# dtype: int64

# %%
df_1_next_round = df_next_round[
    ['Resultado', 'fgk_equipe', 'Ano', 'Rodada', 'Local', 'GP', 'GC', 'Oponente', 'id']
].assign(
    **{'Rodada': lambda x: x['Rodada'].apply(
        lambda y: int(y.split(' ')[-1])
    )}
).sort_values(
    ['fgk_equipe', 'Ano', 'Rodada']
).replace(
    {'Local':{'Visitante':'0', 'Em casa':'1'}}
)

df_1_next_round
# Out:
#      Resultado fgk_equipe        Ano  Rodada Local GP GC  Oponente        id
# 6095             18bb7c10  2022-2023      17     1        7c21e445  18bb7c10
# 6248             19538871  2022-2023      17     1        e4a775cb  19538871
# 6780             33c895d4  2022-2023      17     1        d07537b9  33c895d4
# 6209             361ca564  2022-2023      17     0        cd051869  361ca564
# 6476             47c64c55  2022-2023      17     1        fd962109  47c64c55
# 6590             4ba7cbea  2022-2023      17     0        cff3d9bb  4ba7cbea
# 6628             5bfb9659  2022-2023      17     1        b8fd03ef  5bfb9659
# 6666             7c21e445  2022-2023      17     0        18bb7c10  18bb7c10
# 6286             822bd0ba  2022-2023      17     0        8602292d  822bd0ba
# 6514             8602292d  2022-2023      17     1        822bd0ba  822bd0ba
# 6818             8cec06e1  2022-2023      17     0        d3fd31cc  8cec06e1
# 6552             a2d435b3  2022-2023      17     1        b2b47a98  a2d435b3
# 6172             b2b47a98  2022-2023      17     0        a2d435b3  a2d435b3
# 6132             b8fd03ef  2022-2023      17     0        5bfb9659  5bfb9659
# 6438             cd051869  2022-2023      17     1        361ca564  361ca564
# 6361             cff3d9bb  2022-2023      17     1        4ba7cbea  4ba7cbea
# 6324             d07537b9  2022-2023      17     0        33c895d4  33c895d4
# 6704             d3fd31cc  2022-2023      17     1        8cec06e1  8cec06e1
# 6742             e4a775cb  2022-2023      17     0        19538871  19538871
# 6399             fd962109  2022-2023      17     0        47c64c55  47c64c55

# %% [markdown]
# ## Etapa 2

# %% [markdown]
# ### Tratamento
# <ul>
#     <li> "parm" definie os parametro padrão </li>
#     <ul>
#         <li> <b>window</b> - 5 </li>
#         <li> <b>fields_to_group</b> - fgk_equipe e Ano </li>
#         <li> <b>fields_to_sort</b> - fgk_equipe, Ano e Rodada </li>
#     </ul>
#     <li> Sequenciamento do "Resultado" em "Seq_Resultado"</li>
#     <li> Sequenciamento do "Local" em "Seq_Local" </li>
#     <li> Sequenciamento do "GP" em "Seq_GP" </li>
#     <li> Sequenciamento do "GC" em "Seq_GC" </li>
#     <li> Tratamento do "Seq_Resultado" substituindo: "V" por 2, "E" por 1 e "D" por 0</li>
#     <li> Tratamento de "SSeq_Local", "Seq_GP" e "Seq_GC" preenchendo com zerofill(5)</li>
# </ul>

# %%
parms = {'window': 5, 'fields_to_group': ['fgk_equipe', 'Ano'], 'fields_to_sort':['fgk_equipe', 'Ano', 'Rodada']}

# Resultado
df_1_temp = sequencing(
    **{'df': df_1, 'field_to_sequence': 'Resultado', **parms}
)

# Local
df_1_temp = sequencing(
    **{'df': df_1_temp, 'field_to_sequence': 'Local', **parms}
)

# GP
df_1_temp = sequencing(
    **{'df': df_1_temp, 'field_to_sequence': 'GP', **parms}
)

# GC
df_2 = sequencing(
    **{'df': df_1_temp, 'field_to_sequence': 'GC', **parms}
)

del df_1_temp

df_2 = df_2.assign(
    **{
        'Seq_Resultado': lambda x: x['Seq_Resultado'].str.replace('V', '2').str.replace('E', '1').str.replace('D', '0')
        , 'Seq_Local': lambda x: x['Seq_Local'].astype('int').astype('str').str.zfill(5)
        , 'Seq_GP': lambda x: x['Seq_GP'].astype('int').astype('str').str.zfill(5)
        , 'Seq_GC': lambda x: x['Seq_GC'].astype('int').astype('str').str.zfill(5)
    }
)

df_2
# Out:
#      Resultado fgk_equipe        Ano  Rodada Local GP GC  Oponente        id  \
# 304          D   17892952  2014-2015       1     1  0  1  8602292d  0a235dd1
# 305          E   17892952  2014-2015       2     0  1  1  bd8769d1  ee81980a
# 306          V   17892952  2014-2015       3     0  1  0  b8fd03ef  9e73f0ce
# 307          D   17892952  2014-2015       4     1  0  1  a2d435b3  238517ea
# 308          E   17892952  2014-2015       5     0  2  2  a757999c  e8592bc3
# ...        ...        ...        ...     ...   ... .. ..       ...       ...
# 6204         V   fd962109  2022-2023      12     1  3  0  8602292d  e6102606
# 6205         V   fd962109  2022-2023      13     0  3  2  5bfb9659  d7b30e2b
# 6206         E   fd962109  2022-2023      14     1  0  0  d3fd31cc  9c4402e1
# 6207         D   fd962109  2022-2023      15     0  1  2  b8fd03ef  6ef27b3c
# 6208         D   fd962109  2022-2023      16     1  1  2  19538871  af75b6b0
#
#      Seq_Resultado Seq_Local Seq_GP Seq_GC
# 304              0     00001  00000  00001
# 305             01     00010  00001  00011
# 306            012     00100  00011  00110
# 307           0120     01001  00110  01101
# 308          01201     10010  01102  11012
# ...            ...       ...    ...    ...
# 6204         20012     01011  31123  24320
# 6205         00122     10110  11233  43202
# 6206         01221     01101  12330  32020
# 6207         12210     11010  23301  20202
# 6208         22100     10101  33011  02022
#
# [6372 rows x 13 columns]

# %% [markdown]
# ### Verificação de NA

# %%
df_2.isna().sum()
# Out:
# Resultado        0
# fgk_equipe       0
# Ano              0
# Rodada           0
# Local            0
# GP               0
# GC               0
# Oponente         0
# id               0
# Seq_Resultado    0
# Seq_Local        0
# Seq_GP           0
# Seq_GC           0
# dtype: int64

# %% [markdown]
# ## Etapa 3 e 4

# %% [markdown]
# ### Tratamento dos dados de treino
# <ul>
#     <li>Tratamento da "Rodada" somando +1</li>
#     <li>Tratamento do dataframe com join para obter dados da próxima rodada</li>
#     <ul>
#         <li>Target</li>
#         <li>Target_Oponente</li>
#         <li>GL</li>
#         <li>Target_GP</li>
#         <li>Target_GC</li>
#     </ul>
#     <li>Tratamento do "Target" substituindo: "V" por 2, "E" por 1 e "D" por 0</li>
#     <li>Filtro de Rodadas maiores que 5 e menores que 39</li>
# </ul>

# %%
fields_rodada = ['Resultado', 'fgk_equipe', 'Ano', 'Rodada', 'Local', 'GP', 'GC', 'Oponente', 'id']
fileds_seq = ['Ano', 'fgk_equipe', 'Rodada', 'Seq_Resultado', 'Seq_Local', 'Seq_GP', 'Seq_GC']

df_3 = df_2[fields_rodada].set_index(
    ['Ano', 'fgk_equipe', 'Rodada']
).join(
    df_2[fileds_seq].assign(
        **{'Rodada': lambda x: x['Rodada']+1}
    ).set_index(
        ['Ano', 'fgk_equipe', 'Rodada']
    )
).assign(
    **{'Resultado': lambda x: x['Resultado'].str.replace('V', '2').str.replace('E', '1').str.replace('D', '0')} # Target
).query(
    "Rodada > 5 and Rodada < 39"
)

df_3
# Out:
#                             Resultado Local GP GC  Oponente        id  \
# Ano       fgk_equipe Rodada
# 2014-2015 17892952   6              2     1  1  0  b2b47a98  9d2c4411
#                      7              0     0  1  3  8ef52968  bc4351a4
#                      8              2     1  2  1  fb10988f  6fa0779f
#                      9              0     0  0  1  33c895d4  2be4379e
#                      10             1     1  2  2  7c21e445  c172f461
# ...                               ...   ... .. ..       ...       ...
# 2022-2023 fd962109   12             2     1  3  0  8602292d  e6102606
#                      13             2     0  3  2  5bfb9659  d7b30e2b
#                      14             1     1  0  0  d3fd31cc  9c4402e1
#                      15             0     0  1  2  b8fd03ef  6ef27b3c
#                      16             0     1  1  2  19538871  af75b6b0
#
#                             Seq_Resultado Seq_Local Seq_GP Seq_GC
# Ano       fgk_equipe Rodada
# 2014-2015 17892952   6              01201     10010  01102  11012
#                      7              12012     00101  11021  10120
#                      8              20120     01010  10211  01203
#                      9              01202     10101  02112  12031
#                      10             12020     01010  21120  20311
# ...                                   ...       ...    ...    ...
# 2022-2023 fd962109   12             02001     00101  13112  22432
#                      13             20012     01011  31123  24320
#                      14             00122     10110  11233  43202
#                      15             01221     01101  12330  32020
#                      16             12210     11010  23301  20202
#
# [5472 rows x 10 columns]

# %% [markdown]
# ### Tratamento dos dados da próxima rodada

# %%
df_3_next_round = df_1_next_round[fields_rodada].set_index(
    ['Ano', 'fgk_equipe', 'Rodada']
).join(
    df_2[fileds_seq].assign(
        **{'Rodada': lambda x: x['Rodada']+1}
    ).set_index(
        ['Ano', 'fgk_equipe', 'Rodada']
    )
)
df_3_next_round
# Out:
#                             Resultado Local GP GC  Oponente        id  \
# Ano       fgk_equipe Rodada
# 2022-2023 18bb7c10   17                   1        7c21e445  18bb7c10
#           19538871   17                   1        e4a775cb  19538871
#           33c895d4   17                   1        d07537b9  33c895d4
#           361ca564   17                   0        cd051869  361ca564
#           47c64c55   17                   1        fd962109  47c64c55
#           4ba7cbea   17                   0        cff3d9bb  4ba7cbea
#           5bfb9659   17                   1        b8fd03ef  5bfb9659
#           7c21e445   17                   0        18bb7c10  18bb7c10
#           822bd0ba   17                   0        8602292d  822bd0ba
#           8602292d   17                   1        822bd0ba  822bd0ba
#           8cec06e1   17                   0        d3fd31cc  8cec06e1
#           a2d435b3   17                   1        b2b47a98  a2d435b3
#           b2b47a98   17                   0        a2d435b3  a2d435b3
#           b8fd03ef   17                   0        5bfb9659  5bfb9659
#           cd051869   17                   1        361ca564  361ca564
#           cff3d9bb   17                   1        4ba7cbea  4ba7cbea
#           d07537b9   17                   0        33c895d4  33c895d4
#           d3fd31cc   17                   1        8cec06e1  8cec06e1
#           e4a775cb   17                   0        19538871  19538871
#           fd962109   17                   0        47c64c55  47c64c55
#
#                             Seq_Resultado Seq_Local Seq_GP Seq_GC
# Ano       fgk_equipe Rodada
# 2022-2023 18bb7c10   17             21222     00100  11512  01000
#           19538871   17             21202     10100  21112  01031
#           33c895d4   17             21000     01010  11011  01143
#           361ca564   17             00202     01011  01314  22223
#           47c64c55   17             20220     10100  20120  13011
#           4ba7cbea   17             00002     10101  00233  12340
#           5bfb9659   17             00220     01010  02243  23134
#           7c21e445   17             02000     01011  02010  10122
#           822bd0ba   17             20022     10101  10123  01211
#           8602292d   17             02022     01010  04032  30411
#           8cec06e1   17             00100     01011  10120  24132
#           a2d435b3   17             22022     10100  24022  00100
#           b2b47a98   17             22222     10101  12441  01010
#           b8fd03ef   17             02220     01011  03121  11012
#           cd051869   17             10112     10100  00122  04121
#           cff3d9bb   17             11000     01010  01100  01411
#           d07537b9   17             10220     10101  01431  03122
#           d3fd31cc   17             02100     01010  03000  10023
#           e4a775cb   17             12012     01011  01021  00520
#           fd962109   17             22100     10101  33011  02022

# %% [markdown]
# ### Verificação de NA dados de treino

# %%
df_3.isna().sum()
# Out:
# Resultado         0
# Local             0
# GP                0
# GC                0
# Oponente          0
# id                0
# Seq_Resultado    22
# Seq_Local        22
# Seq_GP           22
# Seq_GC           22
# dtype: int64

# %% [markdown]
# ### Correção dados treino

# %%
#df_4 = df_3

print(df_3.shape)
df_4 = df_3[df_3['Seq_Resultado'].notna()]
print(df_4.shape)
# Out:
# (5472, 10)
# (5450, 10)

# %% [markdown]
# ### Verificação de NA dados da próxima rodada

# %%
df_3_next_round.isna().sum()
# Out:
# Resultado        0
# Local            0
# GP               0
# GC               0
# Oponente         0
# id               0
# Seq_Resultado    0
# Seq_Local        0
# Seq_GP           0
# Seq_GC           0
# dtype: int64

# %% [markdown]
# ### Correção dados da próxima rodada

# %%
print(df_3_next_round.shape)
df_4_next_round = df_3_next_round[df_3_next_round['Resultado'].notna()]
print(df_4_next_round.shape)
# Out:
# (20, 10)
# (20, 10)

# %% [markdown]
# ## Etapa 5 e 6

# %% [markdown]
# ### Tratamento dos dados de treino

# %%
df_5 = pd.DataFrame()

for r in df_4.iterrows():
    df_5 = pd.concat(
        [
            df_5
            , pd.Series({
                **dict(zip(['Ano', 'fgk_equipe', 'Rodada'], r[0]))
                , **seq_to_dict(r[1]['Seq_Resultado'], 'TR')
                , **seq_to_dict(r[1]['Seq_Local'], 'TL')
                , **seq_to_dict(r[1]['Seq_GP'], 'TP')
                , **seq_to_dict(r[1]['Seq_GC'], 'TC')
                , **{
                    'TGL': r[1]['Local']
                    , 'Oponente': r[1]['Oponente']
                    , 'Resultado': r[1]['Resultado']
                    , 'GP': r[1]['GP']
                    , 'GC': r[1]['GC']
                    , 'id': r[1]['id']
                }
            })
        ]
        , axis=1
    )

df_6 = df_5.T
df_6
# Out:
#           Ano fgk_equipe Rodada TR0 TR1 TR2 TR3 TR4 TL0 TL1  ... TC1 TC2 TC3  \
# 0   2014-2015   17892952      6   1   0   2   1   0   0   1  ...   1   0   1
# 0   2014-2015   17892952      7   2   1   0   2   1   1   0  ...   2   1   0
# 0   2014-2015   17892952      8   0   2   1   0   2   0   1  ...   0   2   1
# 0   2014-2015   17892952      9   2   0   2   1   0   1   0  ...   3   0   2
# 0   2014-2015   17892952     10   0   2   0   2   1   0   1  ...   1   3   0
# ..        ...        ...    ...  ..  ..  ..  ..  ..  ..  ..  ...  ..  ..  ..
# 0   2022-2023   fd962109     12   1   0   0   2   0   1   0  ...   3   4   2
# 0   2022-2023   fd962109     13   2   1   0   0   2   1   1  ...   2   3   4
# 0   2022-2023   fd962109     14   2   2   1   0   0   0   1  ...   0   2   3
# 0   2022-2023   fd962109     15   1   2   2   1   0   1   0  ...   2   0   2
# 0   2022-2023   fd962109     16   0   1   2   2   1   0   1  ...   0   2   0
#
#    TC4 TGL  Oponente Resultado GP GC        id
# 0    1   1  b2b47a98         2  1  0  9d2c4411
# 0    1   0  8ef52968         0  1  3  bc4351a4
# 0    0   1  fb10988f         2  2  1  6fa0779f
# 0    1   0  33c895d4         0  0  1  2be4379e
# 0    2   1  7c21e445         1  2  2  c172f461
# ..  ..  ..       ...       ... .. ..       ...
# 0    2   1  8602292d         2  3  0  e6102606
# 0    2   0  5bfb9659         2  3  2  d7b30e2b
# 0    4   1  d3fd31cc         1  0  0  9c4402e1
# 0    3   0  b8fd03ef         0  1  2  6ef27b3c
# 0    2   1  19538871         0  1  2  af75b6b0
#
# [5450 rows x 29 columns]

# %% [markdown]
# ### Tratamento dos dados da próxima rodada

# %%
df_5_next_round = pd.DataFrame()

for r in df_4_next_round.iterrows():
    df_5_next_round = pd.concat(
        [
            df_5_next_round
            , pd.Series({
                **dict(zip(['Ano', 'fgk_equipe', 'Rodada'], r[0]))
                , **seq_to_dict(r[1]['Seq_Resultado'], 'TR')
                , **seq_to_dict(r[1]['Seq_Local'], 'TL')
                , **seq_to_dict(r[1]['Seq_GP'], 'TP')
                , **seq_to_dict(r[1]['Seq_GC'], 'TC')
                , **{
                    'TGL': r[1]['Local']
                    , 'Oponente': r[1]['Oponente']
                    , 'Resultado': r[1]['Resultado']
                    , 'GP': r[1]['GP']
                    , 'GC': r[1]['GC']
                    , 'id': r[1]['id']
                }
            })
        ]
        , axis=1
    )

df_6_next_round = df_5_next_round.T
df_6_next_round
# Out:
#          Ano fgk_equipe Rodada TR0 TR1 TR2 TR3 TR4 TL0 TL1  ... TC1 TC2 TC3  \
# 0  2022-2023   18bb7c10     17   2   2   2   1   2   0   0  ...   0   0   1
# 0  2022-2023   19538871     17   2   0   2   1   2   0   0  ...   3   0   1
# 0  2022-2023   33c895d4     17   0   0   0   1   2   0   1  ...   4   1   1
# 0  2022-2023   361ca564     17   2   0   2   0   0   1   1  ...   2   2   2
# 0  2022-2023   47c64c55     17   0   2   2   0   2   0   0  ...   1   0   3
# 0  2022-2023   4ba7cbea     17   2   0   0   0   0   1   0  ...   4   3   2
# 0  2022-2023   5bfb9659     17   0   2   2   0   0   0   1  ...   3   1   3
# 0  2022-2023   7c21e445     17   0   0   0   2   0   1   1  ...   2   1   0
# 0  2022-2023   822bd0ba     17   2   2   0   0   2   1   0  ...   1   2   1
# 0  2022-2023   8602292d     17   2   2   0   2   0   0   1  ...   1   4   0
# 0  2022-2023   8cec06e1     17   0   0   1   0   0   1   1  ...   3   1   4
# 0  2022-2023   a2d435b3     17   2   2   0   2   2   0   0  ...   0   1   0
# 0  2022-2023   b2b47a98     17   2   2   2   2   2   1   0  ...   1   0   1
# 0  2022-2023   b8fd03ef     17   0   2   2   2   0   1   1  ...   1   0   1
# 0  2022-2023   cd051869     17   2   1   1   0   1   0   0  ...   2   1   4
# 0  2022-2023   cff3d9bb     17   0   0   0   1   1   0   1  ...   1   4   1
# 0  2022-2023   d07537b9     17   0   2   2   0   1   1   0  ...   2   1   3
# 0  2022-2023   d3fd31cc     17   0   0   1   2   0   0   1  ...   2   0   0
# 0  2022-2023   e4a775cb     17   2   1   0   2   1   1   1  ...   2   5   0
# 0  2022-2023   fd962109     17   0   0   1   2   2   1   0  ...   2   0   2
#
#   TC4 TGL  Oponente Resultado GP GC        id
# 0   0   1  7c21e445                  18bb7c10
# 0   0   1  e4a775cb                  19538871
# 0   0   1  d07537b9                  33c895d4
# 0   2   0  cd051869                  361ca564
# 0   1   1  fd962109                  47c64c55
# 0   1   0  cff3d9bb                  4ba7cbea
# 0   2   1  b8fd03ef                  5bfb9659
# 0   1   0  18bb7c10                  18bb7c10
# 0   0   0  8602292d                  822bd0ba
# 0   3   1  822bd0ba                  822bd0ba
# 0   2   0  d3fd31cc                  8cec06e1
# 0   0   1  b2b47a98                  a2d435b3
# 0   0   0  a2d435b3                  a2d435b3
# 0   1   0  5bfb9659                  5bfb9659
# 0   0   1  361ca564                  361ca564
# 0   0   1  4ba7cbea                  4ba7cbea
# 0   0   0  33c895d4                  33c895d4
# 0   1   1  8cec06e1                  8cec06e1
# 0   0   0  19538871                  19538871
# 0   0   0  47c64c55                  47c64c55
#
# [20 rows x 29 columns]

# %% [markdown]
# ### Verificação de NA dados de treino

# %%
df_6.isna().sum()
# Out:
# Ano           0
# fgk_equipe    0
# Rodada        0
# TR0           0
# TR1           0
# TR2           0
# TR3           0
# TR4           0
# TL0           0
# TL1           0
# TL2           0
# TL3           0
# TL4           0
# TP0           0
# TP1           0
# TP2           0
# TP3           0
# TP4           0
# TC0           0
# TC1           0
# TC2           0
# TC3           0
# TC4           0
# TGL           0
# Oponente      0
# Resultado     0
# GP            0
# GC            0
# id            0
# dtype: int64

# %% [markdown]
# ### Verificação de NA dados da próxima rodada

# %%
df_6_next_round.isna().sum()
# Out:
# Ano           0
# fgk_equipe    0
# Rodada        0
# TR0           0
# TR1           0
# TR2           0
# TR3           0
# TR4           0
# TL0           0
# TL1           0
# TL2           0
# TL3           0
# TL4           0
# TP0           0
# TP1           0
# TP2           0
# TP3           0
# TP4           0
# TC0           0
# TC1           0
# TC2           0
# TC3           0
# TC4           0
# TGL           0
# Oponente      0
# Resultado     0
# GP            0
# GC            0
# id            0
# dtype: int64

# %% [markdown]
# ## Etapa Oponente

# %% [markdown]
# ### Tratamento

# %%
campos = list(df_6)
campos
# Out:
# ['Ano',
#  'fgk_equipe',
#  'Rodada',
#  'TR0',
#  'TR1',
#  'TR2',
#  'TR3',
#  'TR4',
#  'TL0',
#  'TL1',
#  'TL2',
#  'TL3',
#  'TL4',
#  'TP0',
#  'TP1',
#  'TP2',
#  'TP3',
#  'TP4',
#  'TC0',
#  'TC1',
#  'TC2',
#  'TC3',
#  'TC4',
#  'TGL',
#  'Oponente',
#  'Resultado',
#  'GP',
#  'GC',
#  'id']

# %%
df_6A = df_6[campos[:campos.index('TGL')+1]]
fields_name = list(df_6A)
fields_name
# Out:
# ['Ano',
#  'fgk_equipe',
#  'Rodada',
#  'TR0',
#  'TR1',
#  'TR2',
#  'TR3',
#  'TR4',
#  'TL0',
#  'TL1',
#  'TL2',
#  'TL3',
#  'TL4',
#  'TP0',
#  'TP1',
#  'TP2',
#  'TP3',
#  'TP4',
#  'TC0',
#  'TC1',
#  'TC2',
#  'TC3',
#  'TC4',
#  'TGL']

# %%
df_6B = df_6A.assign(
    **{'TGL': lambda x: x['TGL'].str.replace('0','x').str.replace('1','0').str.replace('x','1')}
).rename(
    columns=dict(
        zip(
            [fields_name[1]]+fields_name[3:]
            , ['Oponente']+['O'+v[1:] if k>2 else v for k, v in enumerate(fields_name)][3:]
        )
    )
)
df_6B
# Out:
#           Ano  Oponente Rodada OR0 OR1 OR2 OR3 OR4 OL0 OL1  ... OP1 OP2 OP3  \
# 0   2014-2015  17892952      6   1   0   2   1   0   0   1  ...   0   1   1
# 0   2014-2015  17892952      7   2   1   0   2   1   1   0  ...   2   0   1
# 0   2014-2015  17892952      8   0   2   1   0   2   0   1  ...   1   2   0
# 0   2014-2015  17892952      9   2   0   2   1   0   1   0  ...   1   1   2
# 0   2014-2015  17892952     10   0   2   0   2   1   0   1  ...   2   1   1
# ..        ...       ...    ...  ..  ..  ..  ..  ..  ..  ..  ...  ..  ..  ..
# 0   2022-2023  fd962109     12   1   0   0   2   0   1   0  ...   1   1   3
# 0   2022-2023  fd962109     13   2   1   0   0   2   1   1  ...   2   1   1
# 0   2022-2023  fd962109     14   2   2   1   0   0   0   1  ...   3   2   1
# 0   2022-2023  fd962109     15   1   2   2   1   0   1   0  ...   3   3   2
# 0   2022-2023  fd962109     16   0   1   2   2   1   0   1  ...   0   3   3
#
#    OP4 OC0 OC1 OC2 OC3 OC4 OGL
# 0    0   2   1   0   1   1   0
# 0    1   0   2   1   0   1   1
# 0    1   3   0   2   1   0   0
# 0    0   1   3   0   2   1   1
# 0    2   1   1   3   0   2   0
# ..  ..  ..  ..  ..  ..  ..  ..
# 0    1   2   3   4   2   2   0
# 0    3   0   2   3   4   2   1
# 0    1   2   0   2   3   4   0
# 0    1   0   2   0   2   3   1
# 0    2   2   0   2   0   2   0
#
# [5450 rows x 24 columns]

# %% [markdown]
# ### Verificação de NA

# %%
df_6B.isna().sum()
# Out:
# Ano         0
# Oponente    0
# Rodada      0
# OR0         0
# OR1         0
# OR2         0
# OR3         0
# OR4         0
# OL0         0
# OL1         0
# OL2         0
# OL3         0
# OL4         0
# OP0         0
# OP1         0
# OP2         0
# OP3         0
# OP4         0
# OC0         0
# OC1         0
# OC2         0
# OC3         0
# OC4         0
# OGL         0
# dtype: int64

# %%
df_6A_next_round = df_6_next_round[campos[:campos.index('TGL')+1]]
df_6A_next_round
# Out:
#          Ano fgk_equipe Rodada TR0 TR1 TR2 TR3 TR4 TL0 TL1  ... TP1 TP2 TP3  \
# 0  2022-2023   18bb7c10     17   2   2   2   1   2   0   0  ...   1   5   1
# 0  2022-2023   19538871     17   2   0   2   1   2   0   0  ...   1   1   1
# 0  2022-2023   33c895d4     17   0   0   0   1   2   0   1  ...   1   0   1
# 0  2022-2023   361ca564     17   2   0   2   0   0   1   1  ...   1   3   1
# 0  2022-2023   47c64c55     17   0   2   2   0   2   0   0  ...   2   1   0
# 0  2022-2023   4ba7cbea     17   2   0   0   0   0   1   0  ...   3   2   0
# 0  2022-2023   5bfb9659     17   0   2   2   0   0   0   1  ...   4   2   2
# 0  2022-2023   7c21e445     17   0   0   0   2   0   1   1  ...   1   0   2
# 0  2022-2023   822bd0ba     17   2   2   0   0   2   1   0  ...   2   1   0
# 0  2022-2023   8602292d     17   2   2   0   2   0   0   1  ...   3   0   4
# 0  2022-2023   8cec06e1     17   0   0   1   0   0   1   1  ...   2   1   0
# 0  2022-2023   a2d435b3     17   2   2   0   2   2   0   0  ...   2   0   4
# 0  2022-2023   b2b47a98     17   2   2   2   2   2   1   0  ...   4   4   2
# 0  2022-2023   b8fd03ef     17   0   2   2   2   0   1   1  ...   2   1   3
# 0  2022-2023   cd051869     17   2   1   1   0   1   0   0  ...   2   1   0
# 0  2022-2023   cff3d9bb     17   0   0   0   1   1   0   1  ...   0   1   1
# 0  2022-2023   d07537b9     17   0   2   2   0   1   1   0  ...   3   4   1
# 0  2022-2023   d3fd31cc     17   0   0   1   2   0   0   1  ...   0   0   3
# 0  2022-2023   e4a775cb     17   2   1   0   2   1   1   1  ...   2   0   1
# 0  2022-2023   fd962109     17   0   0   1   2   2   1   0  ...   1   0   3
#
#   TP4 TC0 TC1 TC2 TC3 TC4 TGL
# 0   1   0   0   0   1   0   1
# 0   2   1   3   0   1   0   1
# 0   1   3   4   1   1   0   1
# 0   0   3   2   2   2   2   0
# 0   2   1   1   0   3   1   1
# 0   0   0   4   3   2   1   0
# 0   0   4   3   1   3   2   1
# 0   0   2   2   1   0   1   0
# 0   1   1   1   2   1   0   0
# 0   0   1   1   4   0   3   1
# 0   1   2   3   1   4   2   0
# 0   2   0   0   1   0   0   1
# 0   1   0   1   0   1   0   0
# 0   0   2   1   0   1   1   0
# 0   0   1   2   1   4   0   1
# 0   0   1   1   4   1   0   1
# 0   0   2   2   1   3   0   0
# 0   0   3   2   0   0   1   1
# 0   0   0   2   5   0   0   0
# 0   3   2   2   0   2   0   0
#
# [20 rows x 24 columns]

# %%
df_6B_next_round = df_6A_next_round.assign(
    **{'TGL': lambda x: x['TGL'].str.replace('0','x').str.replace('1','0').str.replace('x','1')}
).rename(
    columns=dict(
        zip(
            [fields_name[1]]+fields_name[3:]
            , ['Oponente']+['O'+v[1:] if k>2 else v for k, v in enumerate(fields_name)][3:]
        )
    )
)
df_6B_next_round
# Out:
#          Ano  Oponente Rodada OR0 OR1 OR2 OR3 OR4 OL0 OL1  ... OP1 OP2 OP3  \
# 0  2022-2023  18bb7c10     17   2   2   2   1   2   0   0  ...   1   5   1
# 0  2022-2023  19538871     17   2   0   2   1   2   0   0  ...   1   1   1
# 0  2022-2023  33c895d4     17   0   0   0   1   2   0   1  ...   1   0   1
# 0  2022-2023  361ca564     17   2   0   2   0   0   1   1  ...   1   3   1
# 0  2022-2023  47c64c55     17   0   2   2   0   2   0   0  ...   2   1   0
# 0  2022-2023  4ba7cbea     17   2   0   0   0   0   1   0  ...   3   2   0
# 0  2022-2023  5bfb9659     17   0   2   2   0   0   0   1  ...   4   2   2
# 0  2022-2023  7c21e445     17   0   0   0   2   0   1   1  ...   1   0   2
# 0  2022-2023  822bd0ba     17   2   2   0   0   2   1   0  ...   2   1   0
# 0  2022-2023  8602292d     17   2   2   0   2   0   0   1  ...   3   0   4
# 0  2022-2023  8cec06e1     17   0   0   1   0   0   1   1  ...   2   1   0
# 0  2022-2023  a2d435b3     17   2   2   0   2   2   0   0  ...   2   0   4
# 0  2022-2023  b2b47a98     17   2   2   2   2   2   1   0  ...   4   4   2
# 0  2022-2023  b8fd03ef     17   0   2   2   2   0   1   1  ...   2   1   3
# 0  2022-2023  cd051869     17   2   1   1   0   1   0   0  ...   2   1   0
# 0  2022-2023  cff3d9bb     17   0   0   0   1   1   0   1  ...   0   1   1
# 0  2022-2023  d07537b9     17   0   2   2   0   1   1   0  ...   3   4   1
# 0  2022-2023  d3fd31cc     17   0   0   1   2   0   0   1  ...   0   0   3
# 0  2022-2023  e4a775cb     17   2   1   0   2   1   1   1  ...   2   0   1
# 0  2022-2023  fd962109     17   0   0   1   2   2   1   0  ...   1   0   3
#
#   OP4 OC0 OC1 OC2 OC3 OC4 OGL
# 0   1   0   0   0   1   0   0
# 0   2   1   3   0   1   0   0
# 0   1   3   4   1   1   0   0
# 0   0   3   2   2   2   2   1
# 0   2   1   1   0   3   1   0
# 0   0   0   4   3   2   1   1
# 0   0   4   3   1   3   2   0
# 0   0   2   2   1   0   1   1
# 0   1   1   1   2   1   0   1
# 0   0   1   1   4   0   3   0
# 0   1   2   3   1   4   2   1
# 0   2   0   0   1   0   0   0
# 0   1   0   1   0   1   0   1
# 0   0   2   1   0   1   1   1
# 0   0   1   2   1   4   0   0
# 0   0   1   1   4   1   0   0
# 0   0   2   2   1   3   0   1
# 0   0   3   2   0   0   1   0
# 0   0   0   2   5   0   0   1
# 0   3   2   2   0   2   0   1
#
# [20 rows x 24 columns]

# %% [markdown]
# ## Etapa 7

# %% [markdown]
# ### Tratamento dos dados de treino

# %%
df_7 = df_6.query(
    "TGL.notna()", engine='python'
).set_index(
    ['Ano', 'Oponente', 'Rodada']
).join(
    df_6B.set_index(
        ['Ano', 'Oponente', 'Rodada']
    ).query(
        "OGL.notna()", engine='python'
    )
).reset_index(
)
df_7
# Out:
#             Ano  Oponente  Rodada fgk_equipe TR0 TR1 TR2 TR3 TR4 TL0  ... OP1  \
# 0     2014-2015  b2b47a98       6   17892952   1   0   2   1   0   0  ...   0
# 1     2014-2015  8ef52968       7   17892952   2   1   0   2   1   1  ...   0
# 2     2014-2015  fb10988f       8   17892952   0   2   1   0   2   0  ...   0
# 3     2014-2015  33c895d4       9   17892952   2   0   2   1   0   1  ...   0
# 4     2014-2015  7c21e445      10   17892952   0   2   0   2   1   0  ...   3
# ...         ...       ...     ...        ...  ..  ..  ..  ..  ..  ..  ...  ..
# 5445  2022-2023  8602292d      12   fd962109   1   0   0   2   0   1  ...   1
# 5446  2022-2023  5bfb9659      13   fd962109   2   1   0   0   2   1  ...   0
# 5447  2022-2023  d3fd31cc      14   fd962109   2   2   1   0   0   0  ...   0
# 5448  2022-2023  b8fd03ef      15   fd962109   1   2   2   1   0   1  ...   3
# 5449  2022-2023  19538871      16   fd962109   0   1   2   2   1   0  ...   1
#
#      OP2 OP3 OP4 OC0 OC1 OC2 OC3 OC4 OGL
# 0      3   0   0   2   4   3   0   2   1
# 1      2   0   1   0   0   2   1   1   0
# 2      0   2   3   2   0   1   4   0   1
# 3      2   1   4   0   1   1   0   0   0
# 4      2   1   3   1   1   0   2   1   1
# ...   ..  ..  ..  ..  ..  ..  ..  ..  ..
# 5445   0   1   1   2   1   0   0   1   1
# 5446   1   0   2   2   1   2   0   5   0
# 5447   0   1   2   0   1   2   2   1   1
# 5448   0   4   6   0   1   1   0   3   0
# 5449   1   2   0   3   0   1   0   0   1
#
# [5450 rows x 50 columns]

# %% [markdown]
# ### Tratamento dos dados da próxima rodada

# %%
df_7_next_round = df_6_next_round.query(
    "TGL.notna()", engine='python'
).set_index(
    ['Ano', 'Oponente', 'Rodada']
).join(
    df_6B_next_round.set_index(
        ['Ano', 'Oponente', 'Rodada']
    ).query(
        "OGL.notna()", engine='python'
    )
).reset_index(
)
df_7_next_round
# Out:
#           Ano  Oponente  Rodada fgk_equipe TR0 TR1 TR2 TR3 TR4 TL0  ... OP1  \
# 0   2022-2023  7c21e445      17   18bb7c10   2   2   2   1   2   0  ...   1
# 1   2022-2023  e4a775cb      17   19538871   2   0   2   1   2   0  ...   2
# 2   2022-2023  d07537b9      17   33c895d4   0   0   0   1   2   0  ...   3
# 3   2022-2023  cd051869      17   361ca564   2   0   2   0   0   1  ...   2
# 4   2022-2023  fd962109      17   47c64c55   0   2   2   0   2   0  ...   1
# 5   2022-2023  cff3d9bb      17   4ba7cbea   2   0   0   0   0   1  ...   0
# 6   2022-2023  b8fd03ef      17   5bfb9659   0   2   2   0   0   0  ...   2
# 7   2022-2023  18bb7c10      17   7c21e445   0   0   0   2   0   1  ...   1
# 8   2022-2023  8602292d      17   822bd0ba   2   2   0   0   2   1  ...   3
# 9   2022-2023  822bd0ba      17   8602292d   2   2   0   2   0   0  ...   2
# 10  2022-2023  d3fd31cc      17   8cec06e1   0   0   1   0   0   1  ...   0
# 11  2022-2023  b2b47a98      17   a2d435b3   2   2   0   2   2   0  ...   4
# 12  2022-2023  a2d435b3      17   b2b47a98   2   2   2   2   2   1  ...   2
# 13  2022-2023  5bfb9659      17   b8fd03ef   0   2   2   2   0   1  ...   4
# 14  2022-2023  361ca564      17   cd051869   2   1   1   0   1   0  ...   1
# 15  2022-2023  4ba7cbea      17   cff3d9bb   0   0   0   1   1   0  ...   3
# 16  2022-2023  33c895d4      17   d07537b9   0   2   2   0   1   1  ...   1
# 17  2022-2023  8cec06e1      17   d3fd31cc   0   0   1   2   0   0  ...   2
# 18  2022-2023  19538871      17   e4a775cb   2   1   0   2   1   1  ...   1
# 19  2022-2023  47c64c55      17   fd962109   0   0   1   2   2   1  ...   2
#
#    OP2 OP3 OP4 OC0 OC1 OC2 OC3 OC4 OGL
# 0    0   2   0   2   2   1   0   1   1
# 1    0   1   0   0   2   5   0   0   1
# 2    4   1   0   2   2   1   3   0   1
# 3    1   0   0   1   2   1   4   0   0
# 4    0   3   3   2   2   0   2   0   1
# 5    1   1   0   1   1   4   1   0   0
# 6    1   3   0   2   1   0   1   1   1
# 7    5   1   1   0   0   0   1   0   0
# 8    0   4   0   1   1   4   0   3   0
# 9    1   0   1   1   1   2   1   0   1
# 10   0   3   0   3   2   0   0   1   0
# 11   4   2   1   0   1   0   1   0   1
# 12   0   4   2   0   0   1   0   0   0
# 13   2   2   0   4   3   1   3   2   0
# 14   3   1   0   3   2   2   2   2   1
# 15   2   0   0   0   4   3   2   1   1
# 16   0   1   1   3   4   1   1   0   0
# 17   1   0   1   2   3   1   4   2   1
# 18   1   1   2   1   3   0   1   0   0
# 19   1   0   2   1   1   0   3   1   0
#
# [20 rows x 50 columns]

# %% [markdown]
# ### Verificação de NA dados de treino

# %%
df_7.isna().sum()
# Out:
# Ano           0
# Oponente      0
# Rodada        0
# fgk_equipe    0
# TR0           0
# TR1           0
# TR2           0
# TR3           0
# TR4           0
# TL0           0
# TL1           0
# TL2           0
# TL3           0
# TL4           0
# TP0           0
# TP1           0
# TP2           0
# TP3           0
# TP4           0
# TC0           0
# TC1           0
# TC2           0
# TC3           0
# TC4           0
# TGL           0
# Resultado     0
# GP            0
# GC            0
# id            0
# OR0           4
# OR1           4
# OR2           4
# OR3           4
# OR4           4
# OL0           4
# OL1           4
# OL2           4
# OL3           4
# OL4           4
# OP0           4
# OP1           4
# OP2           4
# OP3           4
# OP4           4
# OC0           4
# OC1           4
# OC2           4
# OC3           4
# OC4           4
# OGL           4
# dtype: int64

# %% [markdown]
# ### Correção dados treino

# %%
print(df_7.shape)
df_8 = df_7[df_7['OR0'].notna()]
print(df_8.shape)
# Out:
# (5450, 50)
# (5446, 50)

# %% [markdown]
# ### Verificação de NA dados da próxima rodada

# %%
df_7_next_round.isna().sum()
# Out:
# Ano           0
# Oponente      0
# Rodada        0
# fgk_equipe    0
# TR0           0
# TR1           0
# TR2           0
# TR3           0
# TR4           0
# TL0           0
# TL1           0
# TL2           0
# TL3           0
# TL4           0
# TP0           0
# TP1           0
# TP2           0
# TP3           0
# TP4           0
# TC0           0
# TC1           0
# TC2           0
# TC3           0
# TC4           0
# TGL           0
# Resultado     0
# GP            0
# GC            0
# id            0
# OR0           0
# OR1           0
# OR2           0
# OR3           0
# OR4           0
# OL0           0
# OL1           0
# OL2           0
# OL3           0
# OL4           0
# OP0           0
# OP1           0
# OP2           0
# OP3           0
# OP4           0
# OC0           0
# OC1           0
# OC2           0
# OC3           0
# OC4           0
# OGL           0
# dtype: int64

# %% [markdown]
# ### Correção dados da próxima rodada

# %%
print(df_7_next_round.shape)
df_8_next_round = df_7_next_round[df_7_next_round['OR0'].notna()]
print(df_8_next_round.shape)
# Out:
# (20, 50)
# (20, 50)

# %% [markdown]
# ### Transformação para type int

# %%
for c in list(df_8):
    if c not in ['Ano', 'Oponente', 'Rodada', 'fgk_equipe', 'id']:
        df_8[c] = df_8[c].astype('int')
    
df_8
# Out:
# <ipython-input-65-4c9b0a7eb55f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_8[c] = df_8[c].astype('int')
#             Ano  Oponente  Rodada fgk_equipe  TR0  TR1  TR2  TR3  TR4  TL0  \
# 0     2014-2015  b2b47a98       6   17892952    1    0    2    1    0    0
# 1     2014-2015  8ef52968       7   17892952    2    1    0    2    1    1
# 2     2014-2015  fb10988f       8   17892952    0    2    1    0    2    0
# 3     2014-2015  33c895d4       9   17892952    2    0    2    1    0    1
# 4     2014-2015  7c21e445      10   17892952    0    2    0    2    1    0
# ...         ...       ...     ...        ...  ...  ...  ...  ...  ...  ...
# 5445  2022-2023  8602292d      12   fd962109    1    0    0    2    0    1
# 5446  2022-2023  5bfb9659      13   fd962109    2    1    0    0    2    1
# 5447  2022-2023  d3fd31cc      14   fd962109    2    2    1    0    0    0
# 5448  2022-2023  b8fd03ef      15   fd962109    1    2    2    1    0    1
# 5449  2022-2023  19538871      16   fd962109    0    1    2    2    1    0
#
#       ...  OP1  OP2  OP3  OP4  OC0  OC1  OC2  OC3  OC4  OGL
# 0     ...    0    3    0    0    2    4    3    0    2    1
# 1     ...    0    2    0    1    0    0    2    1    1    0
# 2     ...    0    0    2    3    2    0    1    4    0    1
# 3     ...    0    2    1    4    0    1    1    0    0    0
# 4     ...    3    2    1    3    1    1    0    2    1    1
# ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 5445  ...    1    0    1    1    2    1    0    0    1    1
# 5446  ...    0    1    0    2    2    1    2    0    5    0
# 5447  ...    0    0    1    2    0    1    2    2    1    1
# 5448  ...    3    0    4    6    0    1    1    0    3    0
# 5449  ...    1    1    2    0    3    0    1    0    0    1
#
# [5446 rows x 50 columns]

# %%
for c in list(df_8_next_round):
    if c not in ['Ano', 'Oponente', 'Rodada', 'fgk_equipe', 'id', 'Resultado', 'GC', 'GP']:
        df_8_next_round[c] = df_8_next_round[c].astype('int')
    
df_8_next_round
# Out:
#           Ano  Oponente  Rodada fgk_equipe  TR0  TR1  TR2  TR3  TR4  TL0  ...  \
# 0   2022-2023  7c21e445      17   18bb7c10    2    2    2    1    2    0  ...
# 1   2022-2023  e4a775cb      17   19538871    2    0    2    1    2    0  ...
# 2   2022-2023  d07537b9      17   33c895d4    0    0    0    1    2    0  ...
# 3   2022-2023  cd051869      17   361ca564    2    0    2    0    0    1  ...
# 4   2022-2023  fd962109      17   47c64c55    0    2    2    0    2    0  ...
# 5   2022-2023  cff3d9bb      17   4ba7cbea    2    0    0    0    0    1  ...
# 6   2022-2023  b8fd03ef      17   5bfb9659    0    2    2    0    0    0  ...
# 7   2022-2023  18bb7c10      17   7c21e445    0    0    0    2    0    1  ...
# 8   2022-2023  8602292d      17   822bd0ba    2    2    0    0    2    1  ...
# 9   2022-2023  822bd0ba      17   8602292d    2    2    0    2    0    0  ...
# 10  2022-2023  d3fd31cc      17   8cec06e1    0    0    1    0    0    1  ...
# 11  2022-2023  b2b47a98      17   a2d435b3    2    2    0    2    2    0  ...
# 12  2022-2023  a2d435b3      17   b2b47a98    2    2    2    2    2    1  ...
# 13  2022-2023  5bfb9659      17   b8fd03ef    0    2    2    2    0    1  ...
# 14  2022-2023  361ca564      17   cd051869    2    1    1    0    1    0  ...
# 15  2022-2023  4ba7cbea      17   cff3d9bb    0    0    0    1    1    0  ...
# 16  2022-2023  33c895d4      17   d07537b9    0    2    2    0    1    1  ...
# 17  2022-2023  8cec06e1      17   d3fd31cc    0    0    1    2    0    0  ...
# 18  2022-2023  19538871      17   e4a775cb    2    1    0    2    1    1  ...
# 19  2022-2023  47c64c55      17   fd962109    0    0    1    2    2    1  ...
#
#     OP1  OP2  OP3  OP4  OC0  OC1  OC2  OC3  OC4  OGL
# 0     1    0    2    0    2    2    1    0    1    1
# 1     2    0    1    0    0    2    5    0    0    1
# 2     3    4    1    0    2    2    1    3    0    1
# 3     2    1    0    0    1    2    1    4    0    0
# 4     1    0    3    3    2    2    0    2    0    1
# 5     0    1    1    0    1    1    4    1    0    0
# 6     2    1    3    0    2    1    0    1    1    1
# 7     1    5    1    1    0    0    0    1    0    0
# 8     3    0    4    0    1    1    4    0    3    0
# 9     2    1    0    1    1    1    2    1    0    1
# 10    0    0    3    0    3    2    0    0    1    0
# 11    4    4    2    1    0    1    0    1    0    1
# 12    2    0    4    2    0    0    1    0    0    0
# 13    4    2    2    0    4    3    1    3    2    0
# 14    1    3    1    0    3    2    2    2    2    1
# 15    3    2    0    0    0    4    3    2    1    1
# 16    1    0    1    1    3    4    1    1    0    0
# 17    2    1    0    1    2    3    1    4    2    1
# 18    1    1    1    2    1    3    0    1    0    0
# 19    2    1    0    2    1    1    0    3    1    0
#
# [20 rows x 50 columns]

# %% [markdown]
# ## Etapa final salvando dataset

# %% [markdown]
# ### Dados de treino

# %%
df_8[
    ['Ano', 'Rodada', 'id', 'fgk_equipe', 'Oponente']
    + ['TR0', 'TR1', 'TR2', 'TR3', 'TR4', 'TL0', 'TL1', 'TL2', 'TL3', 'TL4', 'TP0', 'TP1', 'TP2', 'TP3', 'TP4', 'TC0', 'TC1', 'TC2', 'TC3', 'TC4', 'TGL']
    + ['OR0', 'OR1', 'OR2', 'OR3', 'OR4', 'OL0', 'OL1', 'OL2', 'OL3', 'OL4', 'OP0', 'OP1', 'OP2', 'OP3', 'OP4', 'OC0', 'OC1', 'OC2', 'OC3', 'OC4', 'OGL']
    + ['Resultado', 'GP', 'GC']
].to_parquet('dataset_9.parquet')

# %% [markdown]
# ### Dados da próxima rodada

# %%
df_8_next_round[
    ['Ano', 'Rodada', 'id', 'fgk_equipe', 'Oponente']
    + ['TR0', 'TR1', 'TR2', 'TR3', 'TR4', 'TL0', 'TL1', 'TL2', 'TL3', 'TL4', 'TP0', 'TP1', 'TP2', 'TP3', 'TP4', 'TC0', 'TC1', 'TC2', 'TC3', 'TC4', 'TGL']
    + ['OR0', 'OR1', 'OR2', 'OR3', 'OR4', 'OL0', 'OL1', 'OL2', 'OL3', 'OL4', 'OP0', 'OP1', 'OP2', 'OP3', 'OP4', 'OC0', 'OC1', 'OC2', 'OC3', 'OC4', 'OGL']
#     + ['Resultado', 'GP', 'GC']
].to_parquet('dataset_9_next_round.parquet')
