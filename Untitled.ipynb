# %%
domain = 'https://fbref.com'
br = '/pt/'
pais = 'Brasil'
liga = 'Serie A'

url_brasileirao = 'https://fbref.com/pt/comps/24/Serie-A-Stats'

# %%
domain+"/{lg}/".format(lg=br[1:-1])
# Out:
# 'https://fbref.com/pt/'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
import time

# %%
def get_url(html):
    try:
        resp = html.find("a", href=True)['href']
    except:
        resp = ''
#     print(html)  
#     print(resp)
    return resp

# %%
def get_equipes(url_competion, url, pais='Brasil', liga='Serie A'):
    r = requests.get(
        #url+"/{lg}/".format(lg=language)
        url_competion
    )
    
    soup = BeautifulSoup(r.text, 'lxml')
    
    tbl = soup.find("table", {"class": "stats_table"})
    tbl_h = tbl.find("thead")
    tbl_b = tbl.find("tbody")
    
    table_rows = tbl_b.find_all("tr")
    
    res = []

    for tr in table_rows:
        td = tr.find_all('td')
        a = td[0].find("a", href=True)
        res.append(
            [pais, liga, a.text, url+a['href']]
        )
        
    return pd.DataFrame(
        res
        , columns=['Pais', 'Liga', 'Equipe', 'link']
    ).assign(
        **{'id': lambda x: x['link'].apply(
            lambda y: y.split('/')[-2]
        )}
    )

# %%
parm = {
    'url_competion': 'https://fbref.com/pt/comps/24/Serie-A-Stats'
    , 'url': 'https://fbref.com'
    , 'pais': 'Brasil'
    , 'liga': 'Serie A'
}

df_equipes = get_equipes(**parm)

with open('equipes.json', 'w', encoding='utf-8') as f:
    json.dump(df_equipes.to_dict(orient='records'), f, ensure_ascii=False, indent=4)

# %%
def get_partidas_equipe(domain, url, equipe_id):
    r = requests.get(
        url
    )
    
    soup = BeautifulSoup(r.text, 'lxml')
    
    tbl = soup.find("table", id="matchlogs_for")
    tbl_h = tbl.find("thead")
    tbl_b = tbl.find("tbody")
    
    fields = [th.text.strip() for th in tbl_h.find_all('th')]
    
    res = []
    
    for tr in tbl_b.find_all('tr'):
        res.append(
            [tr.find("th").text.strip()]
            + [
                domain + get_url(td) if i in [8, 16] else td.text.strip() for i, td in enumerate(tr.find_all('td'))
            ]
        )
        
    return pd.DataFrame(
        res
        , columns=fields
    ).assign(
        **{'id':lambda x: x['Relatório da Partida'].apply(
            lambda y: y.split('/')[-2]
        )}
        , **{'Data': lambda x: pd.to_datetime(x['Data'])}
        , **{'fgk_equipe': equipe_id}
        , **{'Oponente': lambda x: x['Oponente'].apply(
            lambda y: y.split('/')[-2]
        )}
    )

# %%
df_partidas = pd.DataFrame()
for row in df_equipes.iterrows():
    df_partidas = pd.concat(
        [
            df_partidas
            , get_partidas_equipe(
                domain
                , row[1]['link']
                , row[1]['id']
            )
        ]
        , ignore_index=True
    )

# %%
df_partidas

# %%
df_partidas.to_excel('partidas.xlsx')

# %%
df_partidas.to_csv('partidas.csv')

# %%
with open('partidas.json', 'w', encoding='utf-8') as f:
    json.dump(df_partidas.to_dict(orient='records'), f, ensure_ascii=False, indent=4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-c844e0100637> in <module>
#       1 with open('partidas.json', 'w', encoding='utf-8') as f:
# ----> 2     json.dump(df_partidas.to_dict(orient='records'), f, ensure_ascii=False, indent=4)
#
# ~\Anaconda3\lib\json\__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# ~\Anaconda3\lib\json\encoder.py in _iterencode(o, _current_indent_level)
#     427             yield _floatstr(o)
#     428         elif isinstance(o, (list, tuple)):
# --> 429             yield from _iterencode_list(o, _current_indent_level)
#     430         elif isinstance(o, dict):
#     431             yield from _iterencode_dict(o, _current_indent_level)
#
# ~\Anaconda3\lib\json\encoder.py in _iterencode_list(lst, _current_indent_level)
#     323                 else:
#     324                     chunks = _iterencode(value, _current_indent_level)
# --> 325                 yield from chunks
#     326         if newline_indent is not None:
#     327             _current_indent_level -= 1
#
# ~\Anaconda3\lib\json\encoder.py in _iterencode_dict(dct, _current_indent_level)
#     403                 else:
#     404                     chunks = _iterencode(value, _current_indent_level)
# --> 405                 yield from chunks
#     406         if newline_indent is not None:
#     407             _current_indent_level -= 1
#
# ~\Anaconda3\lib\json\encoder.py in _iterencode(o, _current_indent_level)
#     436                     raise ValueError("Circular reference detected")
#     437                 markers[markerid] = o
# --> 438             o = _default(o)
#     439             yield from _iterencode(o, _current_indent_level)
#     440             if markers is not None:
#
# ~\Anaconda3\lib\json\encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                         f'is not JSON serializable')
#     181
#
# TypeError: Object of type Timestamp is not JSON serializable

# %%
def get_estatisticas_jogador(url, partida_id, casa, visitante):
    r = requests.get(
        url
    )
    
    soup = BeautifulSoup(r.text, 'lxml')
    
    # jogadores de casa
    try:
        tbl = soup.find("table", id="stats_{team_id}_summary".format(team_id=casa))
        tbl_h = tbl.find("thead")
        tbl_b = tbl.find("tbody")

        fields = [a.text.strip() for a in tbl_h.find_all('tr')[1].find_all('th')]

        res = []

        for tr in tbl_b.find_all('tr'):
            res.append(
                [get_url(tr.find("th"))]
                + [get_url(a) if i == 1 else a.text.strip() for i, a in enumerate(tr.find_all('td'))]
            )
    
        df1 = pd.DataFrame(
            res
            , columns=fields
        ).assign(
            **{'Jogador': lambda x: x['Jogador'].apply(
                lambda y: y.split('/')[-2] if len(y.split('/')) > 1 else y
            )}
            , **{'Nação': lambda x: x['Nação'].apply(
                lambda y: y.split('/')[-2] if len(y.split('/')) > 1 else y
            )}
            , **{'fkg_equipe':casa}
            , **{'fgk_partida': partida_id}
        )
    except:
        df1 = pd.DataFrame()
        print('url', url, 'partida_id', partida_id, 'casa', casa, 'visitante', visitante)
        print('Erro nos jogadores de casa')
        
    # jogadores visitante
    try:
        tbl = soup.find("table", id="stats_{team_id}_summary".format(team_id=visitante))
        tbl_h = tbl.find("thead")
        tbl_b = tbl.find("tbody")

        fields = [a.text.strip() for a in tbl_h.find_all('tr')[1].find_all('th')]

        res = []

        for tr in tbl_b.find_all('tr'):
            res.append(
                [get_url(tr.find("th"))]
                + [url+get_url(a) if i == 1 else a.text.strip() for i, a in enumerate(tr.find_all('td'))]
            )

        df2 = pd.DataFrame(
            res
            , columns=fields
        ).assign(
            **{'Jogador': lambda x: x['Jogador'].apply(
                lambda y: y.split('/')[-2] if len(y.split('/')) > 1 else y
            )}
            , **{'Nação': lambda x: x['Nação'].apply(
                lambda y: y.split('/')[-2] if len(y.split('/')) > 1 else y
            )}
            , **{'fkg_equipe':visitante}
            , **{'fgk_partida': partida_id}
        )
    except:
        df2 = pd.DataFrame()
        print('url', url, 'partida_id', partida_id, 'casa', casa, 'visitante', visitante)
        print('Erro nos jogadores visitantes')
    
    # Goleiro de casa
    try:
        tbl = soup.find("table", id="keeper_stats_{team_id}".format(team_id=casa))
        tbl_h = tbl.find("thead")
        tbl_b = tbl.find("tbody")

        fields = [a.text.strip() for a in tbl_h.find_all('tr')[1].find_all('th')]

        res = []

        for tr in tbl_b.find_all('tr'):
            res.append(
                [get_url(tr.find("th"))]
                + [url+get_url(a) if i == 0 else a.text.strip() for i, a in enumerate(tr.find_all('td'))]
            )

        df3 = pd.DataFrame(
            res
            , columns=fields
        ).assign(
            **{'Jogador': lambda x: x['Jogador'].apply(
                lambda y: y.split('/')[-2] if len(y.split('/')) > 1 else y
            )}
            , **{'Nação': lambda x: x['Nação'].apply(
                lambda y: y.split('/')[-2] if len(y.split('/')) > 1 else y
            )}
            , **{'fkg_equipe':casa}
            , **{'fgk_partida': partida_id}
        )
    except:
        df3 = pd.DataFrame()
        print('url', url, 'partida_id', partida_id, 'casa', casa, 'visitante', visitante)
        print('Erro no goleiro de casa')
    
    # Goleiro visitante
    try:
        tbl = soup.find("table", id="keeper_stats_{team_id}".format(team_id=visitante))
        tbl_h = tbl.find("thead")
        tbl_b = tbl.find("tbody")

        fields = [a.text.strip() for a in tbl_h.find_all('tr')[1].find_all('th')]

        res = []

        for tr in tbl_b.find_all('tr'):
            res.append(
                [get_url(tr.find("th"))]
                + [url+get_url(a) if i == 0 else a.text.strip() for i, a in enumerate(tr.find_all('td'))]
            )

        df4 = pd.DataFrame(
            res
            , columns=fields
        ).assign(
            **{'Jogador': lambda x: x['Jogador'].apply(
                lambda y: y.split('/')[-2] if len(y.split('/')) > 1 else y
            )}
            , **{'Nação': lambda x: x['Nação'].apply(
                lambda y: y.split('/')[-2] if len(y.split('/')) > 1 else y
            )}
            , **{'fkg_equipe':visitante}
            , **{'fgk_partida': partida_id}
        )
    except:
        df4 = pd.DataFrame()
        print('url', url, 'partida_id', partida_id, 'casa', casa, 'visitante', visitante)
        print('Erro no goleiro visitante')
        
    return pd.concat([df1, df2], ignore_index=True), pd.concat([df3, df4], ignore_index=True)

# %%
df_linha = pd.DataFrame()
df_gol = pd.DataFrame()
i = 50
print(i, 'de', len(df_partidas))
if not (df_partidas.iloc[i]['Resultado'] == ''):
    if df_partidas.iloc[i]['Local'] == 'Em casa':
        casa = df_partidas.iloc[i]['fgk_equipe']
        visitante = df_partidas.iloc[i]['Oponente']
    else:
        casa = df_partidas.iloc[i]['Oponente']
        visitante = df_partidas.iloc[i]['fgk_equipe']

    df_linha_t, df_gol_t = get_estatisticas_jogador(
        df_partidas.iloc[i]['Relatório da Partida']
        , df_partidas.iloc[i]['id']
        , casa
        , visitante
    )

    df_linha = pd.concat(
        [df_linha, df_linha_t]
        , ignore_index=True
    )

    df_gol = pd.concat(
        [df_gol, df_gol_t]
        , ignore_index=True
    )
# Out:
# 50 de 911
# url https://fbref.com/pt/partidas/8299b04d/Club-9-de-Octubre-Internacional-2022Abril6-Copa-Sudamericana partida_id 8299b04d casa f7dac7a4 visitante 6f7e1f03
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/8299b04d/Club-9-de-Octubre-Internacional-2022Abril6-Copa-Sudamericana partida_id 8299b04d casa f7dac7a4 visitante 6f7e1f03
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/8299b04d/Club-9-de-Octubre-Internacional-2022Abril6-Copa-Sudamericana partida_id 8299b04d casa f7dac7a4 visitante 6f7e1f03
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/8299b04d/Club-9-de-Octubre-Internacional-2022Abril6-Copa-Sudamericana partida_id 8299b04d casa f7dac7a4 visitante 6f7e1f03
# Erro no goleiro visitante

# %%
df_linha = pd.DataFrame()
df_gol = pd.DataFrame()

c = 0

for row in df_partidas.iterrows():
    print(c, 'de', len(df_partidas))
    if c%10 == 0:
#         time.sleep(10)
        
        
    if not (row[1]['Resultado'] == ''):
        if row[1]['Local'] == 'Em casa':
            casa = row[1]['fgk_equipe']
            visitante = row[1]['Oponente']
        else:
            casa = row[1]['Oponente']
            visitante = row[1]['fgk_equipe']

        df_linha_t, df_gol_t = get_estatisticas_jogador(
            row[1]['Relatório da Partida']
            , row[1]['id']
            , casa
            , visitante
        )

        df_linha = pd.concat(
            [df_linha, df_linha_t]
            , ignore_index=True
        )

        df_gol = pd.concat(
            [df_gol, df_gol_t]
            , ignore_index=True
        )
    c += 1
# Out:
# 0 de 911
# url https://fbref.com/pt/partidas/0c2b92d0/Deportivo-Tachira-Palmeiras-2022Abril6-Copa-Libertadores partida_id 0c2b92d0 casa 7701ed02 visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/0c2b92d0/Deportivo-Tachira-Palmeiras-2022Abril6-Copa-Libertadores partida_id 0c2b92d0 casa 7701ed02 visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/0c2b92d0/Deportivo-Tachira-Palmeiras-2022Abril6-Copa-Libertadores partida_id 0c2b92d0 casa 7701ed02 visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/0c2b92d0/Deportivo-Tachira-Palmeiras-2022Abril6-Copa-Libertadores partida_id 0c2b92d0 casa 7701ed02 visitante abdce579
# Erro no goleiro visitante
# 1 de 911
# url https://fbref.com/pt/partidas/c90739cb/Palmeiras-Ceara-2022Abril9-Serie-A partida_id c90739cb casa abdce579 visitante 2f335e17
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/c90739cb/Palmeiras-Ceara-2022Abril9-Serie-A partida_id c90739cb casa abdce579 visitante 2f335e17
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/c90739cb/Palmeiras-Ceara-2022Abril9-Serie-A partida_id c90739cb casa abdce579 visitante 2f335e17
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/c90739cb/Palmeiras-Ceara-2022Abril9-Serie-A partida_id c90739cb casa abdce579 visitante 2f335e17
# Erro no goleiro visitante
# 2 de 911
# url https://fbref.com/pt/partidas/9cdd9f2a/Palmeiras-Independiente-Petrolero-2022Abril12-Copa-Libertadores partida_id 9cdd9f2a casa abdce579 visitante 8211ee59
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/9cdd9f2a/Palmeiras-Independiente-Petrolero-2022Abril12-Copa-Libertadores partida_id 9cdd9f2a casa abdce579 visitante 8211ee59
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/9cdd9f2a/Palmeiras-Independiente-Petrolero-2022Abril12-Copa-Libertadores partida_id 9cdd9f2a casa abdce579 visitante 8211ee59
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/9cdd9f2a/Palmeiras-Independiente-Petrolero-2022Abril12-Copa-Libertadores partida_id 9cdd9f2a casa abdce579 visitante 8211ee59
# Erro no goleiro visitante
# 3 de 911
# url https://fbref.com/pt/partidas/449b7640/Goias-Palmeiras-2022Abril16-Serie-A partida_id 449b7640 casa 78c617cc visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/449b7640/Goias-Palmeiras-2022Abril16-Serie-A partida_id 449b7640 casa 78c617cc visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/449b7640/Goias-Palmeiras-2022Abril16-Serie-A partida_id 449b7640 casa 78c617cc visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/449b7640/Goias-Palmeiras-2022Abril16-Serie-A partida_id 449b7640 casa 78c617cc visitante abdce579
# Erro no goleiro visitante
# 4 de 911
# url https://fbref.com/pt/partidas/572a91c6/Flamengo-Palmeiras-2022Abril20-Serie-A partida_id 572a91c6 casa 639950ae visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/572a91c6/Flamengo-Palmeiras-2022Abril20-Serie-A partida_id 572a91c6 casa 639950ae visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/572a91c6/Flamengo-Palmeiras-2022Abril20-Serie-A partida_id 572a91c6 casa 639950ae visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/572a91c6/Flamengo-Palmeiras-2022Abril20-Serie-A partida_id 572a91c6 casa 639950ae visitante abdce579
# Erro no goleiro visitante
# 5 de 911
# url https://fbref.com/pt/partidas/8f3f59d1/Palmeiras-Corinthians-2022Abril23-Serie-A partida_id 8f3f59d1 casa abdce579 visitante bf4acd28
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/8f3f59d1/Palmeiras-Corinthians-2022Abril23-Serie-A partida_id 8f3f59d1 casa abdce579 visitante bf4acd28
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/8f3f59d1/Palmeiras-Corinthians-2022Abril23-Serie-A partida_id 8f3f59d1 casa abdce579 visitante bf4acd28
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/8f3f59d1/Palmeiras-Corinthians-2022Abril23-Serie-A partida_id 8f3f59d1 casa abdce579 visitante bf4acd28
# Erro no goleiro visitante
# 6 de 911
# url https://fbref.com/pt/partidas/512bd0ee/CS-Emelec-Palmeiras-2022Abril27-Copa-Libertadores partida_id 512bd0ee casa c1f8ae36 visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/512bd0ee/CS-Emelec-Palmeiras-2022Abril27-Copa-Libertadores partida_id 512bd0ee casa c1f8ae36 visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/512bd0ee/CS-Emelec-Palmeiras-2022Abril27-Copa-Libertadores partida_id 512bd0ee casa c1f8ae36 visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/512bd0ee/CS-Emelec-Palmeiras-2022Abril27-Copa-Libertadores partida_id 512bd0ee casa c1f8ae36 visitante abdce579
# Erro no goleiro visitante
# 7 de 911
# url https://fbref.com/pt/partidas/6e7aced1/Independiente-Petrolero-Palmeiras-2022Maio3-Copa-Libertadores partida_id 6e7aced1 casa 8211ee59 visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/6e7aced1/Independiente-Petrolero-Palmeiras-2022Maio3-Copa-Libertadores partida_id 6e7aced1 casa 8211ee59 visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/6e7aced1/Independiente-Petrolero-Palmeiras-2022Maio3-Copa-Libertadores partida_id 6e7aced1 casa 8211ee59 visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/6e7aced1/Independiente-Petrolero-Palmeiras-2022Maio3-Copa-Libertadores partida_id 6e7aced1 casa 8211ee59 visitante abdce579
# Erro no goleiro visitante
# 8 de 911
# url https://fbref.com/pt/partidas/57b34fd0/Palmeiras-Fluminense-2022Maio8-Serie-A partida_id 57b34fd0 casa abdce579 visitante 84d9701c
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/57b34fd0/Palmeiras-Fluminense-2022Maio8-Serie-A partida_id 57b34fd0 casa abdce579 visitante 84d9701c
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/57b34fd0/Palmeiras-Fluminense-2022Maio8-Serie-A partida_id 57b34fd0 casa abdce579 visitante 84d9701c
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/57b34fd0/Palmeiras-Fluminense-2022Maio8-Serie-A partida_id 57b34fd0 casa abdce579 visitante 84d9701c
# Erro no goleiro visitante
# 9 de 911
# url https://fbref.com/pt/partidas/18175b16/Palmeiras-Bragantino-2022Maio14-Serie-A partida_id 18175b16 casa abdce579 visitante f98930d1
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/18175b16/Palmeiras-Bragantino-2022Maio14-Serie-A partida_id 18175b16 casa abdce579 visitante f98930d1
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/18175b16/Palmeiras-Bragantino-2022Maio14-Serie-A partida_id 18175b16 casa abdce579 visitante f98930d1
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/18175b16/Palmeiras-Bragantino-2022Maio14-Serie-A partida_id 18175b16 casa abdce579 visitante f98930d1
# Erro no goleiro visitante
# 10 de 911
# url https://fbref.com/pt/partidas/741669ec/Palmeiras-CS-Emelec-2022Maio18-Copa-Libertadores partida_id 741669ec casa abdce579 visitante c1f8ae36
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/741669ec/Palmeiras-CS-Emelec-2022Maio18-Copa-Libertadores partida_id 741669ec casa abdce579 visitante c1f8ae36
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/741669ec/Palmeiras-CS-Emelec-2022Maio18-Copa-Libertadores partida_id 741669ec casa abdce579 visitante c1f8ae36
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/741669ec/Palmeiras-CS-Emelec-2022Maio18-Copa-Libertadores partida_id 741669ec casa abdce579 visitante c1f8ae36
# Erro no goleiro visitante
# 11 de 911
# url https://fbref.com/pt/partidas/7201cb97/Juventude-Palmeiras-2022Maio21-Serie-A partida_id 7201cb97 casa d081b697 visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/7201cb97/Juventude-Palmeiras-2022Maio21-Serie-A partida_id 7201cb97 casa d081b697 visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/7201cb97/Juventude-Palmeiras-2022Maio21-Serie-A partida_id 7201cb97 casa d081b697 visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/7201cb97/Juventude-Palmeiras-2022Maio21-Serie-A partida_id 7201cb97 casa d081b697 visitante abdce579
# Erro no goleiro visitante
# 12 de 911
# url https://fbref.com/pt/partidas/91fc4f1a/Palmeiras-Deportivo-Tachira-2022Maio24-Copa-Libertadores partida_id 91fc4f1a casa abdce579 visitante 7701ed02
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/91fc4f1a/Palmeiras-Deportivo-Tachira-2022Maio24-Copa-Libertadores partida_id 91fc4f1a casa abdce579 visitante 7701ed02
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/91fc4f1a/Palmeiras-Deportivo-Tachira-2022Maio24-Copa-Libertadores partida_id 91fc4f1a casa abdce579 visitante 7701ed02
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/91fc4f1a/Palmeiras-Deportivo-Tachira-2022Maio24-Copa-Libertadores partida_id 91fc4f1a casa abdce579 visitante 7701ed02
# Erro no goleiro visitante
# 13 de 911
# url https://fbref.com/pt/partidas/d2e3572b/Santos-Palmeiras-2022Maio29-Serie-A partida_id d2e3572b casa 712c528f visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/d2e3572b/Santos-Palmeiras-2022Maio29-Serie-A partida_id d2e3572b casa 712c528f visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/d2e3572b/Santos-Palmeiras-2022Maio29-Serie-A partida_id d2e3572b casa 712c528f visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/d2e3572b/Santos-Palmeiras-2022Maio29-Serie-A partida_id d2e3572b casa 712c528f visitante abdce579
# Erro no goleiro visitante
# 14 de 911
# url https://fbref.com/pt/partidas/f3433a60/Palmeiras-Atletico-Mineiro-2022Junho5-Serie-A partida_id f3433a60 casa abdce579 visitante 422bb734
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/f3433a60/Palmeiras-Atletico-Mineiro-2022Junho5-Serie-A partida_id f3433a60 casa abdce579 visitante 422bb734
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/f3433a60/Palmeiras-Atletico-Mineiro-2022Junho5-Serie-A partida_id f3433a60 casa abdce579 visitante 422bb734
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/f3433a60/Palmeiras-Atletico-Mineiro-2022Junho5-Serie-A partida_id f3433a60 casa abdce579 visitante 422bb734
# Erro no goleiro visitante
# 15 de 911
# url https://fbref.com/pt/partidas/0b39d24b/Palmeiras-Botafogo-RJ-2022Junho9-Serie-A partida_id 0b39d24b casa abdce579 visitante d9fdd9d9
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/0b39d24b/Palmeiras-Botafogo-RJ-2022Junho9-Serie-A partida_id 0b39d24b casa abdce579 visitante d9fdd9d9
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/0b39d24b/Palmeiras-Botafogo-RJ-2022Junho9-Serie-A partida_id 0b39d24b casa abdce579 visitante d9fdd9d9
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/0b39d24b/Palmeiras-Botafogo-RJ-2022Junho9-Serie-A partida_id 0b39d24b casa abdce579 visitante d9fdd9d9
# Erro no goleiro visitante
# 16 de 911
# url https://fbref.com/pt/partidas/e1b322ef/Coritiba-Palmeiras-2022Junho12-Serie-A partida_id e1b322ef casa d680d257 visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/e1b322ef/Coritiba-Palmeiras-2022Junho12-Serie-A partida_id e1b322ef casa d680d257 visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/e1b322ef/Coritiba-Palmeiras-2022Junho12-Serie-A partida_id e1b322ef casa d680d257 visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/e1b322ef/Coritiba-Palmeiras-2022Junho12-Serie-A partida_id e1b322ef casa d680d257 visitante abdce579
# Erro no goleiro visitante
# 17 de 911
# url https://fbref.com/pt/partidas/3880be62/Palmeiras-Atletico-Goianiense-2022Junho16-Serie-A partida_id 3880be62 casa abdce579 visitante 32d508ca
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/3880be62/Palmeiras-Atletico-Goianiense-2022Junho16-Serie-A partida_id 3880be62 casa abdce579 visitante 32d508ca
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/3880be62/Palmeiras-Atletico-Goianiense-2022Junho16-Serie-A partida_id 3880be62 casa abdce579 visitante 32d508ca
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/3880be62/Palmeiras-Atletico-Goianiense-2022Junho16-Serie-A partida_id 3880be62 casa abdce579 visitante 32d508ca
# Erro no goleiro visitante
# 18 de 911
# url https://fbref.com/pt/partidas/edd7db86/Sao-Paulo-Palmeiras-2022Junho20-Serie-A partida_id edd7db86 casa 5f232eb1 visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/edd7db86/Sao-Paulo-Palmeiras-2022Junho20-Serie-A partida_id edd7db86 casa 5f232eb1 visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/edd7db86/Sao-Paulo-Palmeiras-2022Junho20-Serie-A partida_id edd7db86 casa 5f232eb1 visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/edd7db86/Sao-Paulo-Palmeiras-2022Junho20-Serie-A partida_id edd7db86 casa 5f232eb1 visitante abdce579
# Erro no goleiro visitante
# 19 de 911
# url https://fbref.com/pt/partidas/20ccca64/Avai-Palmeiras-2022Junho26-Serie-A partida_id 20ccca64 casa f205258a visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/20ccca64/Avai-Palmeiras-2022Junho26-Serie-A partida_id 20ccca64 casa f205258a visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/20ccca64/Avai-Palmeiras-2022Junho26-Serie-A partida_id 20ccca64 casa f205258a visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/20ccca64/Avai-Palmeiras-2022Junho26-Serie-A partida_id 20ccca64 casa f205258a visitante abdce579
# Erro no goleiro visitante
# 20 de 911
# url https://fbref.com/pt/partidas/534206ca/Cerro-Porteno-Palmeiras-2022Junho29-Copa-Libertadores partida_id 534206ca casa e4cd6f9a visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/534206ca/Cerro-Porteno-Palmeiras-2022Junho29-Copa-Libertadores partida_id 534206ca casa e4cd6f9a visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/534206ca/Cerro-Porteno-Palmeiras-2022Junho29-Copa-Libertadores partida_id 534206ca casa e4cd6f9a visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/534206ca/Cerro-Porteno-Palmeiras-2022Junho29-Copa-Libertadores partida_id 534206ca casa e4cd6f9a visitante abdce579
# Erro no goleiro visitante
# 21 de 911
# url https://fbref.com/pt/partidas/5e22e3bf/Palmeiras-Atletico-Paranaense-2022Julho2-Serie-A partida_id 5e22e3bf casa abdce579 visitante 2091c619
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/5e22e3bf/Palmeiras-Atletico-Paranaense-2022Julho2-Serie-A partida_id 5e22e3bf casa abdce579 visitante 2091c619
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/5e22e3bf/Palmeiras-Atletico-Paranaense-2022Julho2-Serie-A partida_id 5e22e3bf casa abdce579 visitante 2091c619
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/5e22e3bf/Palmeiras-Atletico-Paranaense-2022Julho2-Serie-A partida_id 5e22e3bf casa abdce579 visitante 2091c619
# Erro no goleiro visitante
# 22 de 911
# url https://fbref.com/pt/partidas/a5e34f0a/Palmeiras-Cerro-Porteno-2022Julho6-Copa-Libertadores partida_id a5e34f0a casa abdce579 visitante e4cd6f9a
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/a5e34f0a/Palmeiras-Cerro-Porteno-2022Julho6-Copa-Libertadores partida_id a5e34f0a casa abdce579 visitante e4cd6f9a
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/a5e34f0a/Palmeiras-Cerro-Porteno-2022Julho6-Copa-Libertadores partida_id a5e34f0a casa abdce579 visitante e4cd6f9a
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/a5e34f0a/Palmeiras-Cerro-Porteno-2022Julho6-Copa-Libertadores partida_id a5e34f0a casa abdce579 visitante e4cd6f9a
# Erro no goleiro visitante
# 23 de 911
# url https://fbref.com/pt/partidas/11f9ed7e/Fortaleza-Palmeiras-2022Julho10-Serie-A partida_id 11f9ed7e casa a9d0ab0e visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/11f9ed7e/Fortaleza-Palmeiras-2022Julho10-Serie-A partida_id 11f9ed7e casa a9d0ab0e visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/11f9ed7e/Fortaleza-Palmeiras-2022Julho10-Serie-A partida_id 11f9ed7e casa a9d0ab0e visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/11f9ed7e/Fortaleza-Palmeiras-2022Julho10-Serie-A partida_id 11f9ed7e casa a9d0ab0e visitante abdce579
# Erro no goleiro visitante
# 24 de 911
# url https://fbref.com/pt/partidas/a5cb4a8c/Palmeiras-Cuiaba-2022Julho18-Serie-A partida_id a5cb4a8c casa abdce579 visitante f0e6fb14
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/a5cb4a8c/Palmeiras-Cuiaba-2022Julho18-Serie-A partida_id a5cb4a8c casa abdce579 visitante f0e6fb14
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/a5cb4a8c/Palmeiras-Cuiaba-2022Julho18-Serie-A partida_id a5cb4a8c casa abdce579 visitante f0e6fb14
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/a5cb4a8c/Palmeiras-Cuiaba-2022Julho18-Serie-A partida_id a5cb4a8c casa abdce579 visitante f0e6fb14
# Erro no goleiro visitante
# 25 de 911
# url https://fbref.com/pt/partidas/7c4516cc/America-MG-Palmeiras-2022Julho21-Serie-A partida_id 7c4516cc casa 1f68d780 visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/7c4516cc/America-MG-Palmeiras-2022Julho21-Serie-A partida_id 7c4516cc casa 1f68d780 visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/7c4516cc/America-MG-Palmeiras-2022Julho21-Serie-A partida_id 7c4516cc casa 1f68d780 visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/7c4516cc/America-MG-Palmeiras-2022Julho21-Serie-A partida_id 7c4516cc casa 1f68d780 visitante abdce579
# Erro no goleiro visitante
# 26 de 911
# url https://fbref.com/pt/partidas/37341666/Palmeiras-Internacional-2022Julho24-Serie-A partida_id 37341666 casa abdce579 visitante 6f7e1f03
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/37341666/Palmeiras-Internacional-2022Julho24-Serie-A partida_id 37341666 casa abdce579 visitante 6f7e1f03
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/37341666/Palmeiras-Internacional-2022Julho24-Serie-A partida_id 37341666 casa abdce579 visitante 6f7e1f03
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/37341666/Palmeiras-Internacional-2022Julho24-Serie-A partida_id 37341666 casa abdce579 visitante 6f7e1f03
# Erro no goleiro visitante
# 27 de 911
# url https://fbref.com/pt/partidas/c2b7baa2/Ceara-Palmeiras-2022Julho30-Serie-A partida_id c2b7baa2 casa 2f335e17 visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/c2b7baa2/Ceara-Palmeiras-2022Julho30-Serie-A partida_id c2b7baa2 casa 2f335e17 visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/c2b7baa2/Ceara-Palmeiras-2022Julho30-Serie-A partida_id c2b7baa2 casa 2f335e17 visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/c2b7baa2/Ceara-Palmeiras-2022Julho30-Serie-A partida_id c2b7baa2 casa 2f335e17 visitante abdce579
# Erro no goleiro visitante
# 28 de 911
# url https://fbref.com/pt/partidas/5f72adbf/Atletico-Mineiro-Palmeiras-2022Agosto3-Copa-Libertadores partida_id 5f72adbf casa 422bb734 visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/5f72adbf/Atletico-Mineiro-Palmeiras-2022Agosto3-Copa-Libertadores partida_id 5f72adbf casa 422bb734 visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/5f72adbf/Atletico-Mineiro-Palmeiras-2022Agosto3-Copa-Libertadores partida_id 5f72adbf casa 422bb734 visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/5f72adbf/Atletico-Mineiro-Palmeiras-2022Agosto3-Copa-Libertadores partida_id 5f72adbf casa 422bb734 visitante abdce579
# Erro no goleiro visitante
# 29 de 911
# 30 de 911
# url https://fbref.com/pt/partidas/47126b45/Palmeiras-Atletico-Mineiro-2022Agosto10-Copa-Libertadores partida_id 47126b45 casa abdce579 visitante 422bb734
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/47126b45/Palmeiras-Atletico-Mineiro-2022Agosto10-Copa-Libertadores partida_id 47126b45 casa abdce579 visitante 422bb734
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/47126b45/Palmeiras-Atletico-Mineiro-2022Agosto10-Copa-Libertadores partida_id 47126b45 casa abdce579 visitante 422bb734
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/47126b45/Palmeiras-Atletico-Mineiro-2022Agosto10-Copa-Libertadores partida_id 47126b45 casa abdce579 visitante 422bb734
# Erro no goleiro visitante
# 31 de 911
# url https://fbref.com/pt/partidas/2efd2b8e/Corinthians-Palmeiras-2022Agosto13-Serie-A partida_id 2efd2b8e casa bf4acd28 visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/2efd2b8e/Corinthians-Palmeiras-2022Agosto13-Serie-A partida_id 2efd2b8e casa bf4acd28 visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/2efd2b8e/Corinthians-Palmeiras-2022Agosto13-Serie-A partida_id 2efd2b8e casa bf4acd28 visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/2efd2b8e/Corinthians-Palmeiras-2022Agosto13-Serie-A partida_id 2efd2b8e casa bf4acd28 visitante abdce579
# Erro no goleiro visitante
# 32 de 911
# url https://fbref.com/pt/partidas/2798ed6f/Palmeiras-Flamengo-2022Agosto21-Serie-A partida_id 2798ed6f casa abdce579 visitante 639950ae
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/2798ed6f/Palmeiras-Flamengo-2022Agosto21-Serie-A partida_id 2798ed6f casa abdce579 visitante 639950ae
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/2798ed6f/Palmeiras-Flamengo-2022Agosto21-Serie-A partida_id 2798ed6f casa abdce579 visitante 639950ae
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/2798ed6f/Palmeiras-Flamengo-2022Agosto21-Serie-A partida_id 2798ed6f casa abdce579 visitante 639950ae
# Erro no goleiro visitante
# 33 de 911
# url https://fbref.com/pt/partidas/106ff936/Fluminense-Palmeiras-2022Agosto27-Serie-A partida_id 106ff936 casa 84d9701c visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/106ff936/Fluminense-Palmeiras-2022Agosto27-Serie-A partida_id 106ff936 casa 84d9701c visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/106ff936/Fluminense-Palmeiras-2022Agosto27-Serie-A partida_id 106ff936 casa 84d9701c visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/106ff936/Fluminense-Palmeiras-2022Agosto27-Serie-A partida_id 106ff936 casa 84d9701c visitante abdce579
# Erro no goleiro visitante
# 34 de 911
# url https://fbref.com/pt/partidas/b3bdba3a/Atletico-Paranaense-Palmeiras-2022Agosto30-Copa-Libertadores partida_id b3bdba3a casa 2091c619 visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/b3bdba3a/Atletico-Paranaense-Palmeiras-2022Agosto30-Copa-Libertadores partida_id b3bdba3a casa 2091c619 visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/b3bdba3a/Atletico-Paranaense-Palmeiras-2022Agosto30-Copa-Libertadores partida_id b3bdba3a casa 2091c619 visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/b3bdba3a/Atletico-Paranaense-Palmeiras-2022Agosto30-Copa-Libertadores partida_id b3bdba3a casa 2091c619 visitante abdce579
# Erro no goleiro visitante
# 35 de 911
# url https://fbref.com/pt/partidas/d8ccaf41/Bragantino-Palmeiras-2022Setembro3-Serie-A partida_id d8ccaf41 casa f98930d1 visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/d8ccaf41/Bragantino-Palmeiras-2022Setembro3-Serie-A partida_id d8ccaf41 casa f98930d1 visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/d8ccaf41/Bragantino-Palmeiras-2022Setembro3-Serie-A partida_id d8ccaf41 casa f98930d1 visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/d8ccaf41/Bragantino-Palmeiras-2022Setembro3-Serie-A partida_id d8ccaf41 casa f98930d1 visitante abdce579
# Erro no goleiro visitante
# 36 de 911
# url https://fbref.com/pt/partidas/0fb977af/Palmeiras-Atletico-Paranaense-2022Setembro6-Copa-Libertadores partida_id 0fb977af casa abdce579 visitante 2091c619
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/0fb977af/Palmeiras-Atletico-Paranaense-2022Setembro6-Copa-Libertadores partida_id 0fb977af casa abdce579 visitante 2091c619
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/0fb977af/Palmeiras-Atletico-Paranaense-2022Setembro6-Copa-Libertadores partida_id 0fb977af casa abdce579 visitante 2091c619
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/0fb977af/Palmeiras-Atletico-Paranaense-2022Setembro6-Copa-Libertadores partida_id 0fb977af casa abdce579 visitante 2091c619
# Erro no goleiro visitante
# 37 de 911
# url https://fbref.com/pt/partidas/9f274e84/Palmeiras-Juventude-2022Setembro10-Serie-A partida_id 9f274e84 casa abdce579 visitante d081b697
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/9f274e84/Palmeiras-Juventude-2022Setembro10-Serie-A partida_id 9f274e84 casa abdce579 visitante d081b697
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/9f274e84/Palmeiras-Juventude-2022Setembro10-Serie-A partida_id 9f274e84 casa abdce579 visitante d081b697
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/9f274e84/Palmeiras-Juventude-2022Setembro10-Serie-A partida_id 9f274e84 casa abdce579 visitante d081b697
# Erro no goleiro visitante
# 38 de 911
# url https://fbref.com/pt/partidas/a39a054a/Palmeiras-Santos-2022Setembro18-Serie-A partida_id a39a054a casa abdce579 visitante 712c528f
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/a39a054a/Palmeiras-Santos-2022Setembro18-Serie-A partida_id a39a054a casa abdce579 visitante 712c528f
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/a39a054a/Palmeiras-Santos-2022Setembro18-Serie-A partida_id a39a054a casa abdce579 visitante 712c528f
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/a39a054a/Palmeiras-Santos-2022Setembro18-Serie-A partida_id a39a054a casa abdce579 visitante 712c528f
# Erro no goleiro visitante
# 39 de 911
# url https://fbref.com/pt/partidas/36f3edc3/Atletico-Mineiro-Palmeiras-2022Setembro28-Serie-A partida_id 36f3edc3 casa 422bb734 visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/36f3edc3/Atletico-Mineiro-Palmeiras-2022Setembro28-Serie-A partida_id 36f3edc3 casa 422bb734 visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/36f3edc3/Atletico-Mineiro-Palmeiras-2022Setembro28-Serie-A partida_id 36f3edc3 casa 422bb734 visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/36f3edc3/Atletico-Mineiro-Palmeiras-2022Setembro28-Serie-A partida_id 36f3edc3 casa 422bb734 visitante abdce579
# Erro no goleiro visitante
# 40 de 911
# url https://fbref.com/pt/partidas/c42e7360/Botafogo-RJ-Palmeiras-2022Outubro3-Serie-A partida_id c42e7360 casa d9fdd9d9 visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/c42e7360/Botafogo-RJ-Palmeiras-2022Outubro3-Serie-A partida_id c42e7360 casa d9fdd9d9 visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/c42e7360/Botafogo-RJ-Palmeiras-2022Outubro3-Serie-A partida_id c42e7360 casa d9fdd9d9 visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/c42e7360/Botafogo-RJ-Palmeiras-2022Outubro3-Serie-A partida_id c42e7360 casa d9fdd9d9 visitante abdce579
# Erro no goleiro visitante
# 41 de 911
# url https://fbref.com/pt/partidas/f2097db0/Palmeiras-Coritiba-2022Outubro6-Serie-A partida_id f2097db0 casa abdce579 visitante d680d257
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/f2097db0/Palmeiras-Coritiba-2022Outubro6-Serie-A partida_id f2097db0 casa abdce579 visitante d680d257
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/f2097db0/Palmeiras-Coritiba-2022Outubro6-Serie-A partida_id f2097db0 casa abdce579 visitante d680d257
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/f2097db0/Palmeiras-Coritiba-2022Outubro6-Serie-A partida_id f2097db0 casa abdce579 visitante d680d257
# Erro no goleiro visitante
# 42 de 911
# url https://fbref.com/pt/partidas/cde5f911/Atletico-Goianiense-Palmeiras-2022Outubro10-Serie-A partida_id cde5f911 casa 32d508ca visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/cde5f911/Atletico-Goianiense-Palmeiras-2022Outubro10-Serie-A partida_id cde5f911 casa 32d508ca visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/cde5f911/Atletico-Goianiense-Palmeiras-2022Outubro10-Serie-A partida_id cde5f911 casa 32d508ca visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/cde5f911/Atletico-Goianiense-Palmeiras-2022Outubro10-Serie-A partida_id cde5f911 casa 32d508ca visitante abdce579
# Erro no goleiro visitante
# 43 de 911
# url https://fbref.com/pt/partidas/e215127f/Palmeiras-Sao-Paulo-2022Outubro16-Serie-A partida_id e215127f casa abdce579 visitante 5f232eb1
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/e215127f/Palmeiras-Sao-Paulo-2022Outubro16-Serie-A partida_id e215127f casa abdce579 visitante 5f232eb1
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/e215127f/Palmeiras-Sao-Paulo-2022Outubro16-Serie-A partida_id e215127f casa abdce579 visitante 5f232eb1
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/e215127f/Palmeiras-Sao-Paulo-2022Outubro16-Serie-A partida_id e215127f casa abdce579 visitante 5f232eb1
# Erro no goleiro visitante
# 44 de 911
# url https://fbref.com/pt/partidas/d16344ec/Palmeiras-Avai-2022Outubro22-Serie-A partida_id d16344ec casa abdce579 visitante f205258a
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/d16344ec/Palmeiras-Avai-2022Outubro22-Serie-A partida_id d16344ec casa abdce579 visitante f205258a
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/d16344ec/Palmeiras-Avai-2022Outubro22-Serie-A partida_id d16344ec casa abdce579 visitante f205258a
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/d16344ec/Palmeiras-Avai-2022Outubro22-Serie-A partida_id d16344ec casa abdce579 visitante f205258a
# Erro no goleiro visitante
# 45 de 911
# url https://fbref.com/pt/partidas/c66640bf/Atletico-Paranaense-Palmeiras-2022Outubro25-Serie-A partida_id c66640bf casa 2091c619 visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/c66640bf/Atletico-Paranaense-Palmeiras-2022Outubro25-Serie-A partida_id c66640bf casa 2091c619 visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/c66640bf/Atletico-Paranaense-Palmeiras-2022Outubro25-Serie-A partida_id c66640bf casa 2091c619 visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/c66640bf/Atletico-Paranaense-Palmeiras-2022Outubro25-Serie-A partida_id c66640bf casa 2091c619 visitante abdce579
# Erro no goleiro visitante
# 46 de 911
# url https://fbref.com/pt/partidas/992de608/Palmeiras-Fortaleza-2022Novembro2-Serie-A partida_id 992de608 casa abdce579 visitante a9d0ab0e
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/992de608/Palmeiras-Fortaleza-2022Novembro2-Serie-A partida_id 992de608 casa abdce579 visitante a9d0ab0e
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/992de608/Palmeiras-Fortaleza-2022Novembro2-Serie-A partida_id 992de608 casa abdce579 visitante a9d0ab0e
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/992de608/Palmeiras-Fortaleza-2022Novembro2-Serie-A partida_id 992de608 casa abdce579 visitante a9d0ab0e
# Erro no goleiro visitante
# 47 de 911
# url https://fbref.com/pt/partidas/9c1e4510/Cuiaba-Palmeiras-2022Novembro6-Serie-A partida_id 9c1e4510 casa f0e6fb14 visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/9c1e4510/Cuiaba-Palmeiras-2022Novembro6-Serie-A partida_id 9c1e4510 casa f0e6fb14 visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/9c1e4510/Cuiaba-Palmeiras-2022Novembro6-Serie-A partida_id 9c1e4510 casa f0e6fb14 visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/9c1e4510/Cuiaba-Palmeiras-2022Novembro6-Serie-A partida_id 9c1e4510 casa f0e6fb14 visitante abdce579
# Erro no goleiro visitante
# 48 de 911
# url https://fbref.com/pt/partidas/596aa98d/Palmeiras-America-MG-2022Novembro9-Serie-A partida_id 596aa98d casa abdce579 visitante 1f68d780
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/596aa98d/Palmeiras-America-MG-2022Novembro9-Serie-A partida_id 596aa98d casa abdce579 visitante 1f68d780
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/596aa98d/Palmeiras-America-MG-2022Novembro9-Serie-A partida_id 596aa98d casa abdce579 visitante 1f68d780
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/596aa98d/Palmeiras-America-MG-2022Novembro9-Serie-A partida_id 596aa98d casa abdce579 visitante 1f68d780
# Erro no goleiro visitante
# 49 de 911
# url https://fbref.com/pt/partidas/67acaa53/Internacional-Palmeiras-2022Novembro13-Serie-A partida_id 67acaa53 casa 6f7e1f03 visitante abdce579
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/67acaa53/Internacional-Palmeiras-2022Novembro13-Serie-A partida_id 67acaa53 casa 6f7e1f03 visitante abdce579
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/67acaa53/Internacional-Palmeiras-2022Novembro13-Serie-A partida_id 67acaa53 casa 6f7e1f03 visitante abdce579
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/67acaa53/Internacional-Palmeiras-2022Novembro13-Serie-A partida_id 67acaa53 casa 6f7e1f03 visitante abdce579
# Erro no goleiro visitante
# 50 de 911
# url https://fbref.com/pt/partidas/8299b04d/Club-9-de-Octubre-Internacional-2022Abril6-Copa-Sudamericana partida_id 8299b04d casa f7dac7a4 visitante 6f7e1f03
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/8299b04d/Club-9-de-Octubre-Internacional-2022Abril6-Copa-Sudamericana partida_id 8299b04d casa f7dac7a4 visitante 6f7e1f03
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/8299b04d/Club-9-de-Octubre-Internacional-2022Abril6-Copa-Sudamericana partida_id 8299b04d casa f7dac7a4 visitante 6f7e1f03
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/8299b04d/Club-9-de-Octubre-Internacional-2022Abril6-Copa-Sudamericana partida_id 8299b04d casa f7dac7a4 visitante 6f7e1f03
# Erro no goleiro visitante
# 51 de 911
# url https://fbref.com/pt/partidas/53471359/Atletico-Mineiro-Internacional-2022Abril10-Serie-A partida_id 53471359 casa 422bb734 visitante 6f7e1f03
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/53471359/Atletico-Mineiro-Internacional-2022Abril10-Serie-A partida_id 53471359 casa 422bb734 visitante 6f7e1f03
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/53471359/Atletico-Mineiro-Internacional-2022Abril10-Serie-A partida_id 53471359 casa 422bb734 visitante 6f7e1f03
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/53471359/Atletico-Mineiro-Internacional-2022Abril10-Serie-A partida_id 53471359 casa 422bb734 visitante 6f7e1f03
# Erro no goleiro visitante
# 52 de 911
# url https://fbref.com/pt/partidas/407e07ae/Internacional-Guairena-FC-2022Abril14-Copa-Sudamericana partida_id 407e07ae casa 6f7e1f03 visitante 257cf097
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/407e07ae/Internacional-Guairena-FC-2022Abril14-Copa-Sudamericana partida_id 407e07ae casa 6f7e1f03 visitante 257cf097
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/407e07ae/Internacional-Guairena-FC-2022Abril14-Copa-Sudamericana partida_id 407e07ae casa 6f7e1f03 visitante 257cf097
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/407e07ae/Internacional-Guairena-FC-2022Abril14-Copa-Sudamericana partida_id 407e07ae casa 6f7e1f03 visitante 257cf097
# Erro no goleiro visitante
# 53 de 911
# url https://fbref.com/pt/partidas/39789423/Internacional-Fortaleza-2022Abril17-Serie-A partida_id 39789423 casa 6f7e1f03 visitante a9d0ab0e
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/39789423/Internacional-Fortaleza-2022Abril17-Serie-A partida_id 39789423 casa 6f7e1f03 visitante a9d0ab0e
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/39789423/Internacional-Fortaleza-2022Abril17-Serie-A partida_id 39789423 casa 6f7e1f03 visitante a9d0ab0e
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/39789423/Internacional-Fortaleza-2022Abril17-Serie-A partida_id 39789423 casa 6f7e1f03 visitante a9d0ab0e
# Erro no goleiro visitante
# 54 de 911
# url https://fbref.com/pt/partidas/8a2778e4/Fluminense-Internacional-2022Abril23-Serie-A partida_id 8a2778e4 casa 84d9701c visitante 6f7e1f03
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/8a2778e4/Fluminense-Internacional-2022Abril23-Serie-A partida_id 8a2778e4 casa 84d9701c visitante 6f7e1f03
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/8a2778e4/Fluminense-Internacional-2022Abril23-Serie-A partida_id 8a2778e4 casa 84d9701c visitante 6f7e1f03
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/8a2778e4/Fluminense-Internacional-2022Abril23-Serie-A partida_id 8a2778e4 casa 84d9701c visitante 6f7e1f03
# Erro no goleiro visitante
# 55 de 911
# url https://fbref.com/pt/partidas/8f07c6b0/Independiente-Internacional-2022Abril26-Copa-Sudamericana partida_id 8f07c6b0 casa 70068101 visitante 6f7e1f03
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/8f07c6b0/Independiente-Internacional-2022Abril26-Copa-Sudamericana partida_id 8f07c6b0 casa 70068101 visitante 6f7e1f03
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/8f07c6b0/Independiente-Internacional-2022Abril26-Copa-Sudamericana partida_id 8f07c6b0 casa 70068101 visitante 6f7e1f03
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/8f07c6b0/Independiente-Internacional-2022Abril26-Copa-Sudamericana partida_id 8f07c6b0 casa 70068101 visitante 6f7e1f03
# Erro no goleiro visitante
# 56 de 911
# url https://fbref.com/pt/partidas/ce0d4b19/Internacional-Avai-2022Maio1-Serie-A partida_id ce0d4b19 casa 6f7e1f03 visitante f205258a
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/ce0d4b19/Internacional-Avai-2022Maio1-Serie-A partida_id ce0d4b19 casa 6f7e1f03 visitante f205258a
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/ce0d4b19/Internacional-Avai-2022Maio1-Serie-A partida_id ce0d4b19 casa 6f7e1f03 visitante f205258a
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/ce0d4b19/Internacional-Avai-2022Maio1-Serie-A partida_id ce0d4b19 casa 6f7e1f03 visitante f205258a
# Erro no goleiro visitante
# 57 de 911
# url https://fbref.com/pt/partidas/11d54347/Guairena-FC-Internacional-2022Maio5-Copa-Sudamericana partida_id 11d54347 casa 257cf097 visitante 6f7e1f03
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/11d54347/Guairena-FC-Internacional-2022Maio5-Copa-Sudamericana partida_id 11d54347 casa 257cf097 visitante 6f7e1f03
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/11d54347/Guairena-FC-Internacional-2022Maio5-Copa-Sudamericana partida_id 11d54347 casa 257cf097 visitante 6f7e1f03
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/11d54347/Guairena-FC-Internacional-2022Maio5-Copa-Sudamericana partida_id 11d54347 casa 257cf097 visitante 6f7e1f03
# Erro no goleiro visitante
# 58 de 911
# url https://fbref.com/pt/partidas/d2e2aafe/Juventude-Internacional-2022Maio8-Serie-A partida_id d2e2aafe casa d081b697 visitante 6f7e1f03
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/d2e2aafe/Juventude-Internacional-2022Maio8-Serie-A partida_id d2e2aafe casa d081b697 visitante 6f7e1f03
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/d2e2aafe/Juventude-Internacional-2022Maio8-Serie-A partida_id d2e2aafe casa d081b697 visitante 6f7e1f03
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/d2e2aafe/Juventude-Internacional-2022Maio8-Serie-A partida_id d2e2aafe casa d081b697 visitante 6f7e1f03
# Erro no goleiro visitante
# 59 de 911
# url https://fbref.com/pt/partidas/d7dc2b5f/Internacional-Corinthians-2022Maio14-Serie-A partida_id d7dc2b5f casa 6f7e1f03 visitante bf4acd28
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/d7dc2b5f/Internacional-Corinthians-2022Maio14-Serie-A partida_id d7dc2b5f casa 6f7e1f03 visitante bf4acd28
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/d7dc2b5f/Internacional-Corinthians-2022Maio14-Serie-A partida_id d7dc2b5f casa 6f7e1f03 visitante bf4acd28
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/d7dc2b5f/Internacional-Corinthians-2022Maio14-Serie-A partida_id d7dc2b5f casa 6f7e1f03 visitante bf4acd28
# Erro no goleiro visitante
# 60 de 911
# url https://fbref.com/pt/partidas/f3698fc6/Internacional-Independiente-2022Maio17-Copa-Sudamericana partida_id f3698fc6 casa 6f7e1f03 visitante 70068101
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/f3698fc6/Internacional-Independiente-2022Maio17-Copa-Sudamericana partida_id f3698fc6 casa 6f7e1f03 visitante 70068101
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/f3698fc6/Internacional-Independiente-2022Maio17-Copa-Sudamericana partida_id f3698fc6 casa 6f7e1f03 visitante 70068101
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/f3698fc6/Internacional-Independiente-2022Maio17-Copa-Sudamericana partida_id f3698fc6 casa 6f7e1f03 visitante 70068101
# Erro no goleiro visitante
# 61 de 911
# url https://fbref.com/pt/partidas/5cbfbe3e/Cuiaba-Internacional-2022Maio21-Serie-A partida_id 5cbfbe3e casa f0e6fb14 visitante 6f7e1f03
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/5cbfbe3e/Cuiaba-Internacional-2022Maio21-Serie-A partida_id 5cbfbe3e casa f0e6fb14 visitante 6f7e1f03
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/5cbfbe3e/Cuiaba-Internacional-2022Maio21-Serie-A partida_id 5cbfbe3e casa f0e6fb14 visitante 6f7e1f03
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/5cbfbe3e/Cuiaba-Internacional-2022Maio21-Serie-A partida_id 5cbfbe3e casa f0e6fb14 visitante 6f7e1f03
# Erro no goleiro visitante
# 62 de 911
# url https://fbref.com/pt/partidas/5c8fd8e7/Internacional-Club-9-de-Octubre-2022Maio24-Copa-Sudamericana partida_id 5c8fd8e7 casa 6f7e1f03 visitante f7dac7a4
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/5c8fd8e7/Internacional-Club-9-de-Octubre-2022Maio24-Copa-Sudamericana partida_id 5c8fd8e7 casa 6f7e1f03 visitante f7dac7a4
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/5c8fd8e7/Internacional-Club-9-de-Octubre-2022Maio24-Copa-Sudamericana partida_id 5c8fd8e7 casa 6f7e1f03 visitante f7dac7a4
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/5c8fd8e7/Internacional-Club-9-de-Octubre-2022Maio24-Copa-Sudamericana partida_id 5c8fd8e7 casa 6f7e1f03 visitante f7dac7a4
# Erro no goleiro visitante
# 63 de 911
# url https://fbref.com/pt/partidas/0621f710/Internacional-Atletico-Goianiense-2022Maio30-Serie-A partida_id 0621f710 casa 6f7e1f03 visitante 32d508ca
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/0621f710/Internacional-Atletico-Goianiense-2022Maio30-Serie-A partida_id 0621f710 casa 6f7e1f03 visitante 32d508ca
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/0621f710/Internacional-Atletico-Goianiense-2022Maio30-Serie-A partida_id 0621f710 casa 6f7e1f03 visitante 32d508ca
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/0621f710/Internacional-Atletico-Goianiense-2022Maio30-Serie-A partida_id 0621f710 casa 6f7e1f03 visitante 32d508ca
# Erro no goleiro visitante
# 64 de 911
# url https://fbref.com/pt/partidas/b3effba3/Bragantino-Internacional-2022Junho5-Serie-A partida_id b3effba3 casa f98930d1 visitante 6f7e1f03
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/b3effba3/Bragantino-Internacional-2022Junho5-Serie-A partida_id b3effba3 casa f98930d1 visitante 6f7e1f03
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/b3effba3/Bragantino-Internacional-2022Junho5-Serie-A partida_id b3effba3 casa f98930d1 visitante 6f7e1f03
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/b3effba3/Bragantino-Internacional-2022Junho5-Serie-A partida_id b3effba3 casa f98930d1 visitante 6f7e1f03
# Erro no goleiro visitante
# 65 de 911
# url https://fbref.com/pt/partidas/8e04e63c/Santos-Internacional-2022Junho8-Serie-A partida_id 8e04e63c casa 712c528f visitante 6f7e1f03
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/8e04e63c/Santos-Internacional-2022Junho8-Serie-A partida_id 8e04e63c casa 712c528f visitante 6f7e1f03
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/8e04e63c/Santos-Internacional-2022Junho8-Serie-A partida_id 8e04e63c casa 712c528f visitante 6f7e1f03
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/8e04e63c/Santos-Internacional-2022Junho8-Serie-A partida_id 8e04e63c casa 712c528f visitante 6f7e1f03
# Erro no goleiro visitante
# 66 de 911
# url https://fbref.com/pt/partidas/b51e9792/Internacional-Flamengo-2022Junho11-Serie-A partida_id b51e9792 casa 6f7e1f03 visitante 639950ae
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/b51e9792/Internacional-Flamengo-2022Junho11-Serie-A partida_id b51e9792 casa 6f7e1f03 visitante 639950ae
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/b51e9792/Internacional-Flamengo-2022Junho11-Serie-A partida_id b51e9792 casa 6f7e1f03 visitante 639950ae
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/b51e9792/Internacional-Flamengo-2022Junho11-Serie-A partida_id b51e9792 casa 6f7e1f03 visitante 639950ae
# Erro no goleiro visitante
# 67 de 911
# url https://fbref.com/pt/partidas/3049aab7/Goias-Internacional-2022Junho15-Serie-A partida_id 3049aab7 casa 78c617cc visitante 6f7e1f03
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/3049aab7/Goias-Internacional-2022Junho15-Serie-A partida_id 3049aab7 casa 78c617cc visitante 6f7e1f03
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/3049aab7/Goias-Internacional-2022Junho15-Serie-A partida_id 3049aab7 casa 78c617cc visitante 6f7e1f03
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/3049aab7/Goias-Internacional-2022Junho15-Serie-A partida_id 3049aab7 casa 78c617cc visitante 6f7e1f03
# Erro no goleiro visitante
# 68 de 911
# url https://fbref.com/pt/partidas/93d7983b/Internacional-Botafogo-RJ-2022Junho19-Serie-A partida_id 93d7983b casa 6f7e1f03 visitante d9fdd9d9
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/93d7983b/Internacional-Botafogo-RJ-2022Junho19-Serie-A partida_id 93d7983b casa 6f7e1f03 visitante d9fdd9d9
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/93d7983b/Internacional-Botafogo-RJ-2022Junho19-Serie-A partida_id 93d7983b casa 6f7e1f03 visitante d9fdd9d9
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/93d7983b/Internacional-Botafogo-RJ-2022Junho19-Serie-A partida_id 93d7983b casa 6f7e1f03 visitante d9fdd9d9
# Erro no goleiro visitante
# 69 de 911
# url https://fbref.com/pt/partidas/ed828cae/Internacional-Coritiba-2022Junho24-Serie-A partida_id ed828cae casa 6f7e1f03 visitante d680d257
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/ed828cae/Internacional-Coritiba-2022Junho24-Serie-A partida_id ed828cae casa 6f7e1f03 visitante d680d257
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/ed828cae/Internacional-Coritiba-2022Junho24-Serie-A partida_id ed828cae casa 6f7e1f03 visitante d680d257
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/ed828cae/Internacional-Coritiba-2022Junho24-Serie-A partida_id ed828cae casa 6f7e1f03 visitante d680d257
# Erro no goleiro visitante
# 70 de 911
# url https://fbref.com/pt/partidas/71e1519e/Colo-Colo-Internacional-2022Junho28-Copa-Sudamericana partida_id 71e1519e casa 2ff539f3 visitante 6f7e1f03
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/71e1519e/Colo-Colo-Internacional-2022Junho28-Copa-Sudamericana partida_id 71e1519e casa 2ff539f3 visitante 6f7e1f03
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/71e1519e/Colo-Colo-Internacional-2022Junho28-Copa-Sudamericana partida_id 71e1519e casa 2ff539f3 visitante 6f7e1f03
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/71e1519e/Colo-Colo-Internacional-2022Junho28-Copa-Sudamericana partida_id 71e1519e casa 2ff539f3 visitante 6f7e1f03
# Erro no goleiro visitante
# 71 de 911
# url https://fbref.com/pt/partidas/378f0336/Ceara-Internacional-2022Julho2-Serie-A partida_id 378f0336 casa 2f335e17 visitante 6f7e1f03
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/378f0336/Ceara-Internacional-2022Julho2-Serie-A partida_id 378f0336 casa 2f335e17 visitante 6f7e1f03
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/378f0336/Ceara-Internacional-2022Julho2-Serie-A partida_id 378f0336 casa 2f335e17 visitante 6f7e1f03
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/378f0336/Ceara-Internacional-2022Julho2-Serie-A partida_id 378f0336 casa 2f335e17 visitante 6f7e1f03
# Erro no goleiro visitante
# 72 de 911
# url https://fbref.com/pt/partidas/6f976215/Internacional-Colo-Colo-2022Julho5-Copa-Sudamericana partida_id 6f976215 casa 6f7e1f03 visitante 2ff539f3
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/6f976215/Internacional-Colo-Colo-2022Julho5-Copa-Sudamericana partida_id 6f976215 casa 6f7e1f03 visitante 2ff539f3
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/6f976215/Internacional-Colo-Colo-2022Julho5-Copa-Sudamericana partida_id 6f976215 casa 6f7e1f03 visitante 2ff539f3
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/6f976215/Internacional-Colo-Colo-2022Julho5-Copa-Sudamericana partida_id 6f976215 casa 6f7e1f03 visitante 2ff539f3
# Erro no goleiro visitante
# 73 de 911
# url https://fbref.com/pt/partidas/3504ef52/Internacional-America-MG-2022Julho11-Serie-A partida_id 3504ef52 casa 6f7e1f03 visitante 1f68d780
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/3504ef52/Internacional-America-MG-2022Julho11-Serie-A partida_id 3504ef52 casa 6f7e1f03 visitante 1f68d780
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/3504ef52/Internacional-America-MG-2022Julho11-Serie-A partida_id 3504ef52 casa 6f7e1f03 visitante 1f68d780
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/3504ef52/Internacional-America-MG-2022Julho11-Serie-A partida_id 3504ef52 casa 6f7e1f03 visitante 1f68d780
# Erro no goleiro visitante
# 74 de 911
# url https://fbref.com/pt/partidas/3b523ceb/Atletico-Paranaense-Internacional-2022Julho16-Serie-A partida_id 3b523ceb casa 2091c619 visitante 6f7e1f03
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/3b523ceb/Atletico-Paranaense-Internacional-2022Julho16-Serie-A partida_id 3b523ceb casa 2091c619 visitante 6f7e1f03
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/3b523ceb/Atletico-Paranaense-Internacional-2022Julho16-Serie-A partida_id 3b523ceb casa 2091c619 visitante 6f7e1f03
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/3b523ceb/Atletico-Paranaense-Internacional-2022Julho16-Serie-A partida_id 3b523ceb casa 2091c619 visitante 6f7e1f03
# Erro no goleiro visitante
# 75 de 911
# url https://fbref.com/pt/partidas/4528e677/Internacional-Sao-Paulo-2022Julho20-Serie-A partida_id 4528e677 casa 6f7e1f03 visitante 5f232eb1
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/4528e677/Internacional-Sao-Paulo-2022Julho20-Serie-A partida_id 4528e677 casa 6f7e1f03 visitante 5f232eb1
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/4528e677/Internacional-Sao-Paulo-2022Julho20-Serie-A partida_id 4528e677 casa 6f7e1f03 visitante 5f232eb1
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/4528e677/Internacional-Sao-Paulo-2022Julho20-Serie-A partida_id 4528e677 casa 6f7e1f03 visitante 5f232eb1
# Erro no goleiro visitante
# 76 de 911
# url https://fbref.com/pt/partidas/37341666/Palmeiras-Internacional-2022Julho24-Serie-A partida_id 37341666 casa abdce579 visitante 6f7e1f03
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/37341666/Palmeiras-Internacional-2022Julho24-Serie-A partida_id 37341666 casa abdce579 visitante 6f7e1f03
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/37341666/Palmeiras-Internacional-2022Julho24-Serie-A partida_id 37341666 casa abdce579 visitante 6f7e1f03
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/37341666/Palmeiras-Internacional-2022Julho24-Serie-A partida_id 37341666 casa abdce579 visitante 6f7e1f03
# Erro no goleiro visitante
# 77 de 911
# url https://fbref.com/pt/partidas/7f8213a9/Internacional-Atletico-Mineiro-2022Julho31-Serie-A partida_id 7f8213a9 casa 6f7e1f03 visitante 422bb734
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/7f8213a9/Internacional-Atletico-Mineiro-2022Julho31-Serie-A partida_id 7f8213a9 casa 6f7e1f03 visitante 422bb734
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/7f8213a9/Internacional-Atletico-Mineiro-2022Julho31-Serie-A partida_id 7f8213a9 casa 6f7e1f03 visitante 422bb734
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/7f8213a9/Internacional-Atletico-Mineiro-2022Julho31-Serie-A partida_id 7f8213a9 casa 6f7e1f03 visitante 422bb734
# Erro no goleiro visitante
# 78 de 911
# url https://fbref.com/pt/partidas/02d31da0/Melgar-Internacional-2022Agosto4-Copa-Sudamericana partida_id 02d31da0 casa 87ffd947 visitante 6f7e1f03
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/02d31da0/Melgar-Internacional-2022Agosto4-Copa-Sudamericana partida_id 02d31da0 casa 87ffd947 visitante 6f7e1f03
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/02d31da0/Melgar-Internacional-2022Agosto4-Copa-Sudamericana partida_id 02d31da0 casa 87ffd947 visitante 6f7e1f03
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/02d31da0/Melgar-Internacional-2022Agosto4-Copa-Sudamericana partida_id 02d31da0 casa 87ffd947 visitante 6f7e1f03
# Erro no goleiro visitante
# 79 de 911
# url https://fbref.com/pt/partidas/20f714ea/Fortaleza-Internacional-2022Agosto7-Serie-A partida_id 20f714ea casa a9d0ab0e visitante 6f7e1f03
# Erro nos jogadores de casa
# url https://fbref.com/pt/partidas/20f714ea/Fortaleza-Internacional-2022Agosto7-Serie-A partida_id 20f714ea casa a9d0ab0e visitante 6f7e1f03
# Erro nos jogadores visitantes
# url https://fbref.com/pt/partidas/20f714ea/Fortaleza-Internacional-2022Agosto7-Serie-A partida_id 20f714ea casa a9d0ab0e visitante 6f7e1f03
# Erro no goleiro de casa
# url https://fbref.com/pt/partidas/20f714ea/Fortaleza-Internacional-2022Agosto7-Serie-A partida_id 20f714ea casa a9d0ab0e visitante 6f7e1f03
# Erro no goleiro visitante
# 80 de 911
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-5b2a2e3b16c7> in <module>
#      18             visitante = row[1]['fgk_equipe']
#      19
# ---> 20         df_linha_t, df_gol_t = get_estatisticas_jogador(
#      21             row[1]['Relatório da Partida']
#      22             , row[1]['id']
#
# <ipython-input-11-1bda729603b5> in get_estatisticas_jogador(url, partida_id, casa, visitante)
#       1 def get_estatisticas_jogador(url, partida_id, casa, visitante):
# ----> 2     r = requests.get(
#       3         url
#       4     )
#       5
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379         # Trigger any extra validation we need to do.
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#     383             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     976         # Force connect early to allow us to validate the connection.
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#     980         if not conn.is_verified:
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     360             context.load_default_certs()
#     361
# --> 362         self.sock = ssl_wrap_socket(
#     363             sock=conn,
#     364             keyfile=self.key_file,
#
# ~\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data)
#     384     ) or IS_SECURETRANSPORT:
#     385         if HAS_SNI and server_hostname is not None:
# --> 386             return context.wrap_socket(sock, server_hostname=server_hostname)
#     387
#     388         warnings.warn(
#
# ~\Anaconda3\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     498         # SSLSocket class handles server_hostname encoding before it calls
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#     502             server_side=server_side,
#
# ~\Anaconda3\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1038                         # non-blocking
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#    1042                 self.close()
#
# ~\Anaconda3\lib\ssl.py in do_handshake(self, block)
#    1307             if timeout == 0.0 and block:
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#    1311             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
# df_equipes
# df_partidas
# df_linha
# df_gol

# %%
df_partidas.query("fgk_equipe == 'abdce579'").iloc[35]['Resultado'] == ''

# %%
link = df_partidas.iloc[0]['Relatório da Partida']
link

# %%
partida_id = df_partidas.iloc[0]['id']
partida_id

# %%
casa = df_partidas.iloc[0]['Oponente']
casa

# %%
visitante = df_partidas.iloc[0]['fgk_equipe']
visitante

# %%
r = requests.get(
    link
)
soup = BeautifulSoup(r.text, 'lxml')
tbl = soup.find("table", id="keeper_stats_{team_id}".format(team_id=casa))

tbl_h = tbl.find("thead")
tbl_b = tbl.find("tbody")

fields = [a.text.strip() for a in tbl_h.find_all('tr')[1].find_all('th')]

res = []

for tr in tbl_b.find_all('tr'):
    res.append(
        [tr.find("th").find("a", href=True)['href']]
        + [url+a.find("a", href=True)['href'] if i == 0 else a.text.strip() for i, a in enumerate(tr.find_all('td'))]
    )
    
pd.DataFrame(
    res
    , columns=fields
).assign(
    **{'Jogador': lambda x: x['Jogador'].apply(
        lambda y: y.split('/')[-2]
    )}
    , **{'Nação': lambda x: x['Nação'].apply(
        lambda y: y.split('/')[-2]
    )}
    , **{'fkg_equipe':casa}
    , **{'fgk_partida': partida_id}
)

# %%
pd.DataFrame(res, columns=fields).assign(
    **{'ID':lambda x: x['Relatório da Partida'].apply(
        lambda y: y.split('/')[-2]
    )}
    , **{'Data': lambda x: pd.to_datetime(x['Data'])}
)

# %%
df_equipes.assign(
    **{'id': lambda x: x['link'].apply(
        lambda y: y.split('/')[-2]
    )}
)

# %%
table_rows = tbl_b.find_all("tr")

res = []

for tr in table_rows:
    td = tr.find_all('td')
    a = td[0].find("a", href=True)
    res.append(
        [pais, liga, a.text, url+a['href']]
    )

# %%
df_equipes = pd.DataFrame(res, columns=['Pais', 'Liga', 'Equipe', 'link'])

# %%
df_equipes['link'].iloc[0]

# %%
fields = []
cells = tbl_h.find_all("th")
fields = [cell.text.strip() for cell in cells if cell.text.strip()][1:]

# %%
table_rows = tbl_b.find_all("tr")

res = []

for tr in table_rows:
    td = tr.find_all('td')
#     row = [cell.text.strip() for cell in td if cell.text.strip()]
    row = [cell.text for cell in td if cell.text.strip()]
    if row:
        res.append(row)

# %%
df = pd.DataFrame(res, columns=fields)
df['Equipe']

# %%
tbl_b

# %%
for i, v in enumerate(['a', 'b', 'c']):
    print(i, v)
